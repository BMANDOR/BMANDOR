# %% [markdown]
# <a href="https://colab.research.google.com/github/BMANDOR/BMANDOR/blob/main/Copy_of_Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("CO2 emissions world data.csv")
data.head()
# Out:
#   Substance EDGAR Country Code                 Country        1970  \
# 0       CO2                ABW                   Aruba    0.081876
# 1       CO2                AFG             Afghanistan    1.739541
# 2       CO2                AGO                  Angola    8.952570
# 3       CO2                AIA                Anguilla    0.002168
# 4       CO2                AIR  International Aviation  169.300997
#
#          1971        1972        1973        1974        1975        1976  \
# 0    0.081889    0.095415    0.099630    0.089089    0.105139    0.096041
# 1    1.737823    1.715749    1.742813    2.198551    2.037627    1.899895
# 2    8.538308   10.388519   11.372301   11.833761   10.930423    7.317385
# 3    0.002168    0.002264    0.002109    0.002350    0.002584    0.002434
# 4  169.300997  179.147487  186.892096  179.793331  173.866020  174.273791
#
#    ...        2012        2013        2014        2015        2016  \
# ...

# %%
columns_to_drop = ['Substance', 'EDGAR Country Code'] + [str(year) for year in range(1970, 1990)]
data = data.drop(columns=columns_to_drop, errors='ignore')

# %%
data.head()
# Out:
#                   Country        1990        1991        1992        1993  \
# 0                   Aruba    0.524847    0.620443    0.720163    0.691391
# 1             Afghanistan    2.910442    2.778890    1.696297    1.626566
# 2                  Angola   11.298197   11.851036   12.196366   12.213651
# 3                Anguilla    0.006114    0.007579    0.007903    0.009952
# 4  International Aviation  258.993781  251.900903  260.067858  265.022085
#
#          1994        1995        1996        1997        1998  ...  \
# 0    0.757696    0.814652    0.544440    0.831664    0.832856  ...
# 1    1.555483    1.380338    1.353128    1.337146    1.347632  ...
# 2   11.568319   13.039689   15.773126   16.500580   17.138055  ...
# 3    0.013131    0.016396    0.016213    0.013564    0.012449  ...
# 4  278.583570  289.103425  300.847663  315.607704  326.243076  ...
#
#          2012        2013        2014        2015        2016        2017  \
# ...

# %%
data = data.set_index('Country')

# %%
brazil_C02_data = data.loc['Brazil']

print(brazil_C02_data)
# Out:
# 1990    228.603035
# 1991    235.896819
# 1992    239.335705
# 1993    250.505454
# 1994    258.807161
# 1995    278.612488
# 1996    301.951476
# 1997    322.439560
# 1998    332.368130
# 1999    341.675538
# 2000    364.751870
# 2001    365.659482
# 2002    365.512830
# 2003    365.861225
# 2004    382.382184
# 2005    385.321073
# 2006    388.565459
# 2007    405.580573
# 2008    425.532830
# 2009    397.670767
# 2010    450.435927
# 2011    470.163744
# 2012    506.651873
# 2013    532.936838
# 2014    559.341955
# 2015    527.939104
# 2016    493.511293
# 2017    504.151474
# 2018    480.141718
# 2019    478.170180
# 2020    441.369024
# 2021    489.857734
# Name: Brazil, dtype: float64

# %%
Gini=pd.read_csv("swiid.csv")
Gini = Gini[['country','year', 'gini_disp']]
Gini = Gini.pivot(index='country', columns='year', values='gini_disp')
Gini = Gini.astype(int, errors='ignore')

# %%
import matplotlib.pyplot as plt

brazil_data = Gini.loc['Brazil']


plt.figure(figsize=(10, 6))
plt.plot(brazil_data.index, brazil_data.values, marker='o', linestyle='-', label='Brazil')


treatment_year1 = 2001
plt.axvline(x=treatment_year1, color='red', linestyle='--', label=f'Bolsa Escola: {treatment_year1}')

treatment_year2 = 2003
plt.axvline(x=treatment_year2, color='yellow', linestyle='--', label=f'Bolsa Família & start of L. I. Lula da Silvas presidency : {treatment_year2}')


treatment_year3 = 2011
plt.axvline(x=treatment_year3, color='green', linestyle='--', label=f'End of L. I. Lula da Silvas presidency: {treatment_year3}')


treatment_year4 = 2016
plt.axvline(x=treatment_year4, color='pink', linestyle='--', label=f'End of Dilma Rousseff presidency: {treatment_year4}')

treatment_year5 = 2018
plt.axvline(x=treatment_year5, color='orange', linestyle='--', label=f'End of Michel Temer presidency/beginning of Bolsonaro presidency: {treatment_year5}')






plt.title('Gini Index for Brazil Over the Years')
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

Chile_data = Gini.loc['Chile']


plt.figure(figsize=(10, 6))
plt.plot(Chile_data.index, Chile_data.values, marker='o', linestyle='-', label='Chile')



plt.title('Gini Index for Chile Over the Years')
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
Chile_C02_data = data.loc['Chile']

print(Chile_C02_data)
# Out:
# 1990    33.016758
# 1991    31.470621
# 1992    32.662348
# 1993    34.556129
# 1994    37.718665
# 1995    41.303151
# 1996    47.464203
# 1997    54.025606
# 1998    54.488704
# 1999    57.071688
# 2000    53.427346
# 2001    51.357134
# 2002    51.828925
# 2003    53.784774
# 2004    58.088964
# 2005    58.881315
# 2006    60.017909
# 2007    67.465103
# 2008    71.012243
# 2009    67.946159
# 2010    72.065103
# 2011    78.660831
# 2012    80.849933
# 2013    84.987906
# 2014    78.469540
# 2015    84.065666
# 2016    88.570009
# 2017    89.339973
# 2018    89.060492
# 2019    94.009749
# 2020    83.495113
# 2021    85.703287
# Name: Chile, dtype: float64

# %%
# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
Chile_C02_data = pd.DataFrame({'Chile': [33.016758, 31.470621, 32.662348, 34.556129, 37.718665, 41.303151,
                                          47.464203, 54.025606, 54.488704, 57.071688, 53.427346, 51.357134,
                                          51.828925, 53.784774, 58.088964, 58.881315, 60.017909, 67.465103,
                                          71.012243, 67.946159,  72.065103, 78.660831, 80.849933, 84.987906,
                                          78.469540, 84.065666, 88.570009, 89.339973, 89.060492, 94.009749,
                                          83.495113,   85.703287]},
                                    index=range(1990, 2022))




gini_df = pd.DataFrame({'Gini': Chile_data.values}, index=Chile_data.index)

# Reindex both DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
Chile_C02_data_data = Chile_C02_data.reindex(all_years)
gini_df = gini_df.reindex(all_years)

# Concatenate the DataFrames along the columns axis
combined1 = pd.concat([gini_df, Chile_C02_data], axis=1)

# Display the combined dataframe
print(combined1)
# Out:
#       Gini      Chile
# 1990  50.4  33.016758
# 1991  50.4  31.470621
# 1992  50.6  32.662348
# 1993  50.6  34.556129
# 1994  50.6  37.718665
# 1995  50.6  41.303151
# 1996  50.6  47.464203
# 1997  50.7  54.025606
# 1998  50.8  54.488704
# 1999  50.7  57.071688
# 2000  50.7  53.427346
# 2001  50.4  51.357134
# 2002  50.2  51.828925
# 2003  49.9  53.784774
# 2004  49.3  58.088964
# 2005  48.6  58.881315
# 2006  48.0  60.017909
# 2007  47.8  67.465103
# 2008  47.6  71.012243
# 2009  47.4  67.946159
# 2010  47.0  72.065103
# 2011  46.7  78.660831
# 2012  46.4  80.849933
# 2013  46.1  84.987906
# 2014  45.8  78.469540
# 2015  45.5  84.065666
# 2016  45.6  88.570009
# 2017  45.7  89.339973
# 2018  45.5  89.060492
# 2019  45.4  94.009749
# 2020  45.3  83.495113
# 2021   NaN  85.703287

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined1.index, combined1['Chile'], color='blue', marker='o', label='CO2 Emissions')
ax1.set_xlabel('Year')
ax1.set_ylabel('CO2 Emissions', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined1.index, combined1['Gini'], color='green', marker='o', label='Gini Index Chile')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')


# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('CO2 Emissions and Gini Index over Years (1990-2021)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
Argentina_gini_data = Gini.loc['Argentina']
print(Argentina_gini_data)
# Out:
# year
# 1960     NaN
# 1961    36.3
# 1962    36.2
# 1963    36.1
# 1964    36.0
#         ...
# 2018    37.8
# 2019    37.9
# 2020    37.9
# 2021    37.8
# 2022     NaN
# Name: Argentina, Length: 63, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.plot(Argentina_gini_data.index, Argentina_gini_data.values, marker='o', linestyle='-', label='Argentina')



plt.title('Gini Index for Argentina Over the Years')
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
Argentina_data = Gini.loc['Argentina']

# %%
# Assuming 'argentina_C02_data' is the DataFrame for CO2 data for Argentina
argentina_C02_data = pd.DataFrame({'Argentina': [100.664657, 106.008404, 108.350133, 112.135473, 115.877568, 118.003760,
                                                  128.915356, 133.403221, 140.107162, 142.533980, 139.429555, 133.815991,
                                                  125.887675, 139.765361, 154.912713, 158.685343, 168.072936, 177.640687,
                                                  183.316128, 168.779385, 180.945731, 189.985371, 191.774376, 198.151363,
                                                  195.952635, 199.417385, 197.383313, 194.257588, 192.035130, 183.172298,
                                                  171.863250, 189.002027]},
                                    index=range(1990, 2022))
gini_df1 = pd.DataFrame({'Gini': Argentina_data.values}, index=Argentina_data.index)

# Reindex both DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
argentina_C02_data = argentina_C02_data.reindex(all_years)
gini_df1 = gini_df.reindex(all_years)

# Concatenate the DataFrames along the columns axis
combined2 = pd.concat([gini_df1 , argentina_C02_data], axis=1)

# Display the combined dataframe
print(combined2)
# Out:
#       Gini   Argentina
# Year
# 1990  50.4  100.664657
# 1991  50.4  106.008404
# 1992  50.6  108.350133
# 1993  50.6  112.135473
# 1994  50.6  115.877568
# 1995  50.6  118.003760
# 1996  50.6  128.915356
# 1997  50.7  133.403221
# 1998  50.8  140.107162
# 1999  50.7  142.533980
# 2000  50.7  139.429555
# 2001  50.4  133.815991
# 2002  50.2  125.887675
# 2003  49.9  139.765361
# 2004  49.3  154.912713
# 2005  48.6  158.685343
# 2006  48.0  168.072936
# 2007  47.8  177.640687
# 2008  47.6  183.316128
# 2009  47.4  168.779385
# 2010  47.0  180.945731
# 2011  46.7  189.985371
# 2012  46.4  191.774376
# 2013  46.1  198.151363
# 2014  45.8  195.952635
# 2015  45.5  199.417385
# 2016  45.6  197.383313
# 2017  45.7  194.257588
# 2018  45.5  192.035130
# 2019  45.4  183.172298
# 2020  45.3  171.863250
# 2021   NaN  189.002027

# %%
fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined2.index, combined2['Argentina'], color='blue', marker='o', label='CO2 Emissions')
ax1.set_xlabel('Year')
ax1.set_ylabel('CO2 Emissions', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined2.index, combined2['Gini'], color='green', marker='o', label='Gini Index Argentina')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')


# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('CO2 Emissions and Gini Index over Years (1990-2021)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
Mexico_gini_data = Gini.loc['Mexico']
Mexico_gini_data.tail()
# Out:
# year
# 2018    42.9
# 2019    42.7
# 2020    42.6
# 2021     NaN
# 2022     NaN
# Name: Mexico, dtype: float64

# %%
plt.figure(figsize=(15, 6))  # Adjust the figure size for a wider plot
plt.plot(Mexico_gini_data.index, Mexico_gini_data.values, marker='o', linestyle='-', label='Mexico')

plt.title('Gini Index for Mexico Over the Years')
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.grid(True)

treatment_year = 1997
plt.axvline(x=treatment_year, color='red', linestyle='--', label=f'PROGRESA: {treatment_year}')

# Set tick frequency to show every year
plt.xticks(range(Mexico_gini_data.index.min(), Mexico_gini_data.index.max() + 1), rotation=45)

# Adjust the x-axis limits for a wider scale
plt.xlim(Mexico_gini_data.index.min() - 1, Mexico_gini_data.index.max() + 1)

plt.legend()
plt.show()

# %%
Mexico_C02_data = data.loc['Mexico']

print(Mexico_C02_data)
# Out:
# 1990    291.037419
# 1991    308.825276
# 1992    312.796549
# 1993    320.782325
# 1994    346.396731
# 1995    326.669563
# 1996    342.638613
# 1997    361.831732
# 1998    384.262957
# 1999    373.418741
# 2000    397.968255
# 2001    395.777641
# 2002    401.834863
# 2003    421.982340
# 2004    431.716344
# 2005    448.861298
# 2006    465.476110
# 2007    472.479441
# 2008    473.890536
# 2009    464.121821
# 2010    479.374450
# 2011    489.196071
# 2012    508.500731
# 2013    495.694950
# 2014    482.752772
# 2015    491.483172
# 2016    498.818222
# 2017    501.223555
# 2018    484.649408
# 2019    481.464227
# 2020    401.125707
# 2021    418.347939
# Name: Mexico, dtype: float64

# %%
import pandas as pd

# Assuming 'mexico_gini_data' is the DataFrame for Gini data
gini_df_mexico = pd.DataFrame({'Gini': Mexico_gini_data.values}, index=Mexico_gini_data.index)

# DataFrame for Annual CO₂ emissions (per capita) data for Mexico
co2_data_mexico = pd.DataFrame({'Mexico': [3.879598, 3.960730, 3.915376, 3.901596, 3.983983, 3.680608, 3.731603,
                                           3.892123, 4.023621, 4.009665, 4.002362, 4.102153, 4.067756, 4.258348,
                                           4.221425, 4.397130, 4.441561, 4.374283, 4.313347, 4.146058, 4.057475,
                                           4.234802, 4.332987, 4.224420, 4.076545, 3.991013, 3.948262, 3.790490,
                                           3.792204, 3.744022, 3.510278, 3.699861]},
                                index=range(1990, 2022))

# Reindex both DataFrames to ensure they have the same index
all_years_mexico = pd.Index(range(1990, 2022), name='Year')
co2_data_mexico = co2_data_mexico.reindex(all_years_mexico)
gini_df_mexico = gini_df_mexico.reindex(all_years_mexico)

# Concatenate the DataFrames along the columns axis
combined_mexico = pd.concat([gini_df_mexico, co2_data_mexico], axis=1)

# Display the combined dataframe
print(combined_mexico)
# Out:
#       Gini    Mexico
# Year
# 1990  48.1  3.879598
# 1991  48.5  3.960730
# 1992  48.9  3.915376
# 1993  49.2  3.901596
# 1994  49.4  3.983983
# 1995  49.5  3.680608
# 1996  49.3  3.731603
# 1997  49.3  3.892123
# 1998  49.3  4.023621
# 1999  49.0  4.009665
# 2000  48.8  4.002362
# 2001  48.3  4.102153
# 2002  47.9  4.067756
# 2003  47.5  4.258348
# 2004  47.1  4.221425
# 2005  46.8  4.397130
# 2006  46.6  4.441561
# 2007  46.7  4.374283
# 2008  46.8  4.313347
# 2009  46.4  4.146058
# 2010  46.0  4.057475
# 2011  45.8  4.234802
# 2012  45.7  4.332987
# 2013  45.3  4.224420
# 2014  44.9  4.076545
# 2015  44.3  3.991013
# 2016  43.6  3.948262
# 2017  43.3  3.790490
# 2018  42.9  3.792204
# 2019  42.7  3.744022
# 2020  42.6  3.510278
# 2021   NaN  3.699861

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined_mexico.index, combined_mexico['Mexico'], color='blue', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined_mexico.index, combined_mexico['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')

treatment_yearx = 1997
plt.axvline(x=treatment_yearx, color='red', linestyle='--', label=f'Oportunidades: {treatment_yearx}')

# Show all years on the x-axis
plt.xticks(combined_mexico.index, rotation=45)

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita) and Gini Index over Years in Mexico (1990-2021)')
plt.legend()
plt.show()

# %%
C02_per_capita =pd.read_csv('co-emissions-per-capita.csv')
C02_per_capita
# Out:
#             Entity Code  Year  Annual CO₂ emissions (per capita)
# 0      Afghanistan  AFG  1949                           0.001992
# 1      Afghanistan  AFG  1950                           0.011266
# 2      Afghanistan  AFG  1951                           0.012098
# 3      Afghanistan  AFG  1952                           0.011946
# 4      Afghanistan  AFG  1953                           0.013685
# ...            ...  ...   ...                                ...
# 26595     Zimbabwe  ZWE  2018                           0.711830
# 26596     Zimbabwe  ZWE  2019                           0.636645
# 26597     Zimbabwe  ZWE  2020                           0.500945
# 26598     Zimbabwe  ZWE  2021                           0.524972
# 26599     Zimbabwe  ZWE  2022                           0.542628
#
# [26600 rows x 4 columns]

# %%
C02_per_capita_Mexico = C02_per_capita[C02_per_capita['Entity'] == 'Mexico']
C02_per_capita_Mexico
# Out:
#        Entity Code  Year  Annual CO₂ emissions (per capita)
# 15446  Mexico  MEX  1891                           0.044496
# 15447  Mexico  MEX  1892                           0.048828
# 15448  Mexico  MEX  1893                           0.044171
# 15449  Mexico  MEX  1894                           0.044140
# 15450  Mexico  MEX  1895                           0.039958
# ...       ...  ...   ...                                ...
# 15573  Mexico  MEX  2018                           3.792204
# 15574  Mexico  MEX  2019                           3.744022
# 15575  Mexico  MEX  2020                           3.510278
# 15576  Mexico  MEX  2021                           3.699861
# 15577  Mexico  MEX  2022                           4.015337
#
# [132 rows x 4 columns]

# %%
gdp_per_capita =pd.read_csv('gdp-per-capita-worldbank.csv')
C02_per_capita_Mexico_timeframe = C02_per_capita_Mexico[(C02_per_capita_Mexico ['Year'] >= 1990) & (C02_per_capita_Mexico ['Year'] <= 2021)]
C02_per_capita_Mexico_timeframe
# Out:
#        Entity Code  Year  Annual CO₂ emissions (per capita)
# 15545  Mexico  MEX  1990                           3.879598
# 15546  Mexico  MEX  1991                           3.960730
# 15547  Mexico  MEX  1992                           3.915376
# 15548  Mexico  MEX  1993                           3.901596
# 15549  Mexico  MEX  1994                           3.983983
# 15550  Mexico  MEX  1995                           3.680608
# 15551  Mexico  MEX  1996                           3.731603
# 15552  Mexico  MEX  1997                           3.892123
# 15553  Mexico  MEX  1998                           4.023621
# 15554  Mexico  MEX  1999                           4.009665
# 15555  Mexico  MEX  2000                           4.002362
# 15556  Mexico  MEX  2001                           4.102153
# 15557  Mexico  MEX  2002                           4.067756
# 15558  Mexico  MEX  2003                           4.258348
# 15559  Mexico  MEX  2004                           4.221425
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'C02_per_capita_brazil_timeframe' is the DataFrame for CO2 data within the specified timeframe
# Make sure to replace 'Year' and 'Annual CO₂ emissions (per capita)' with the actual column names in your DataFrame

co2_emissions = C02_per_capita_Mexico_timeframe ['Annual CO₂ emissions (per capita)']


# Plotting
plt.figure(figsize=(12, 6))

treatment_yearx = 1997
plt.axvline(x=treatment_yearx, color='red', linestyle='--', label=f'Oportunidades: {treatment_yearx}')

plt.plot(co2_emissions, marker='o', linestyle='-', color='blue')
plt.title('Annual CO₂ Emissions per Capita in Mexico (1990-2021)')
plt.xlabel('Year')
plt.ylabel('Annual CO₂ emissions (tonnes per person per capita)')
plt.grid(True)
plt.legend()
plt.show()

# %%
Mexico_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Mexico']
Mexico_gdp_data.head()
# Out:
#       Entity Code  Year  GDP per capita, PPP (constant 2017 international $)
# 3679  Mexico  MEX  1990                                          15355.628
# 3680  Mexico  MEX  1991                                          15689.659
# 3681  Mexico  MEX  1992                                          15931.482
# 3682  Mexico  MEX  1993                                          15930.484
# 3683  Mexico  MEX  1994                                          16402.258

# %%
# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
Mexico_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Mexico']

# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
C02_per_capita_Mexico_timeframe = C02_per_capita_Mexico[(C02_per_capita_Mexico ['Year'] >= 1990) & (C02_per_capita_Mexico ['Year'] <= 2021)]

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df = pd.DataFrame({'Gini': Mexico_gini_data.values}, index= Mexico_gini_data.index)

# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
gdp_df = pd.DataFrame({'GDP': Mexico_gdp_data ['GDP per capita, PPP (constant 2017 international $)'].values},
                      index=Mexico_gdp_data ['Year'])

# Reindex all DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
C02_per_capita_Mexico_timeframe = C02_per_capita_Mexico_timeframe.set_index('Year').reindex(all_years)

gini_df = gini_df.reindex(all_years)
gdp_df = gdp_df.reindex(all_years)

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(C02_per_capita_Mexico_timeframe.index, C02_per_capita_Mexico_timeframe['Annual CO₂ emissions (per capita)'], color='blue', marker='o', )
ax1.set_xlabel('Year')
ax1.set_xticks(C02_per_capita_Mexico_timeframe.index)
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Set a linear scale for the y-axis

# ... (rest of the code rema ins the same)


# ... (rest of the code remains the same)




ax2 = ax1.twinx()
line2, = ax2.plot(gini_df.index, gini_df['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Add a third y-axis for GDP
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
line3, = ax3.plot(gdp_df.index, gdp_df['GDP'], color='red', marker='o')
ax3.set_ylabel('GDP per capita in $', color='red')
ax3.tick_params(axis='y', labelcolor='red')
# ... (previous code remains the same)

# Show legend for all lines outside the graph on the right side

# ... (rest of the code remains the same)



treatment_year = 1997
plt.axvline(x=treatment_year, color='red', linestyle='--', label=f'Oportunidades: {treatment_year}')



lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(0.1, 0.1 ))

lines = [line1, line2, line3]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(1.2, 1.2), borderaxespad=0.)






# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita), Gini Index, and GDP per Capita over Years in Mexico (1990-2021)')
plt.tight_layout()
plt.legend()
plt.show()

# %%
C02_per_capita_Peru = C02_per_capita[C02_per_capita['Entity'] == 'Peru']
C02_per_capita_Peru_timeframe = C02_per_capita_Peru[(C02_per_capita_Peru ['Year'] >= 1990) & (C02_per_capita_Peru ['Year'] <= 2021)]
print(C02_per_capita_Peru_timeframe)
# Out:
#       Entity Code  Year  Annual CO₂ emissions (per capita)
# 19036   Peru  PER  1990                           0.967963
# 19037   Peru  PER  1991                           0.919182
# 19038   Peru  PER  1992                           0.910555
# 19039   Peru  PER  1993                           1.015772
# 19040   Peru  PER  1994                           1.008060
# 19041   Peru  PER  1995                           1.028385
# 19042   Peru  PER  1996                           0.992363
# 19043   Peru  PER  1997                           1.093899
# 19044   Peru  PER  1998                           1.086913
# 19045   Peru  PER  1999                           1.126091
# 19046   Peru  PER  2000                           1.075901
# 19047   Peru  PER  2001                           0.940808
# 19048   Peru  PER  2002                           0.930670
# 19049   Peru  PER  2003                           0.893288
# 19050   Peru  PER  2004                           1.015782
# ...

# %%
Peru_gini_data = Gini.loc['Peru']
Peru_gini_data.tail()
# Out:
# year
# 2018    44.4
# 2019    44.2
# 2020    44.8
# 2021    44.4
# 2022     NaN
# Name: Peru, dtype: float64

# %%
import pandas as pd

# Assuming 'peru_gini_data' is the DataFrame for Gini data
gini_df = pd.DataFrame({'Gini': Peru_gini_data.values}, index=Peru_gini_data.index)

# DataFrame for Annual CO₂ emissions (per capita) data for Peru
co2_data_peru = pd.DataFrame({'Peru': [0.967963, 0.919182, 0.910555, 1.015772, 1.008060, 1.028385, 0.992363,
                                       1.093899, 1.086913, 1.126091, 1.075901, 0.940808, 0.930670, 0.893288,
                                       1.015782, 1.077231, 0.993524, 1.199493, 1.225384, 1.362019, 1.454181,
                                       1.430676, 1.529724, 1.432277, 1.627081, 1.602895, 1.693802, 1.735741,
                                       1.734205, 1.778074, 1.410164, 1.674903]},
                               index=range(1990, 2022))

# Reindex both DataFrames to ensure they have the same index
all_years_peru = pd.Index(range(1990, 2022), name='Year')
co2_data_peru = co2_data_peru.reindex(all_years_peru)
gini_df = gini_df.reindex(all_years_peru)

# Concatenate the DataFrames along the columns axis
combined_peru = pd.concat([gini_df, co2_data_peru], axis=1)

# Display the combined dataframe
print(combined_peru)
# Out:
#       Gini      Peru
# Year
# 1990  53.6  0.967963
# 1991  53.5  0.919182
# 1992  53.4  0.910555
# 1993  53.2  1.015772
# 1994  53.1  1.008060
# 1995  52.9  1.028385
# 1996  52.7  0.992363
# 1997  52.4  1.093899
# 1998  52.5  1.086913
# 1999  52.1  1.126091
# 2000  51.1  1.075901
# 2001  51.4  0.940808
# 2002  52.1  0.930670
# 2003  52.5  0.893288
# 2004  52.3  1.015782
# 2005  51.7  1.077231
# 2006  51.0  0.993524
# 2007  50.3  1.199493
# 2008  49.4  1.225384
# 2009  48.6  1.362019
# 2010  47.9  1.454181
# 2011  47.1  1.430676
# 2012  46.5  1.529724
# 2013  45.9  1.432277
# 2014  45.3  1.627081
# 2015  45.2  1.602895
# 2016  45.0  1.693802
# 2017  44.6  1.735741
# 2018  44.4  1.734205
# 2019  44.2  1.778074
# 2020  44.8  1.410164
# 2021  44.4  1.674903

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined_peru.index, combined_peru['Peru'], color='blue', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined_peru.index, combined_peru['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')

treatment_yearx = 2005
plt.axvline(x=treatment_yearx, color='red', linestyle='--', label=f'Juntus: {treatment_yearx}')

# Show all years on the x-axis
plt.xticks(combined_peru.index, rotation=45)

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita) and Gini Index over Years in Peru (1990-2021)')
plt.legend()
plt.show()

# %%
Peru_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Peru']
Peru_gdp_data.head()
# Out:
#      Entity Code  Year  GDP per capita, PPP (constant 2017 international $)
# 4535   Peru  PER  1990                                          5240.2580
# 4536   Peru  PER  1991                                          5244.1445
# 4537   Peru  PER  1992                                          5110.7373
# 4538   Peru  PER  1993                                          5271.9820
# 4539   Peru  PER  1994                                          5804.9995

# %%
Peru_gini_data = Gini.loc['Peru']
Peru_gini_data.tail()
# Out:
# year
# 2018    44.4
# 2019    44.2
# 2020    44.8
# 2021    44.4
# 2022     NaN
# Name: Peru, dtype: float64

# %%
# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
Peru_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Peru']

# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
C02_per_capita_Peru_timeframe = C02_per_capita_Peru[(C02_per_capita_Peru ['Year'] >= 1990) & (C02_per_capita_Peru ['Year'] <= 2021)]

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df = pd.DataFrame({'Gini': Peru_gini_data.values}, index= Peru_gini_data.index)

# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
gdp_df = pd.DataFrame({'GDP': Peru_gdp_data ['GDP per capita, PPP (constant 2017 international $)'].values},
                      index=Peru_gdp_data['Year'])

# Reindex all DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
C02_per_capita_Peru_timeframe = C02_per_capita_Peru_timeframe.set_index('Year').reindex(all_years)

gini_df = gini_df.reindex(all_years)
gdp_df = gdp_df.reindex(all_years)

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(C02_per_capita_Peru_timeframe.index, C02_per_capita_Peru_timeframe['Annual CO₂ emissions (per capita)'], color='blue', marker='o', )
ax1.set_xlabel('Year')
ax1.set_xticks(C02_per_capita_Peru_timeframe.index)
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Set a linear scale for the y-axis

# ... (rest of the code rema ins the same)


# ... (rest of the code remains the same)




ax2 = ax1.twinx()
line2, = ax2.plot(gini_df.index, gini_df['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Add a third y-axis for GDP
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
line3, = ax3.plot(gdp_df.index, gdp_df['GDP'], color='red', marker='o')
ax3.set_ylabel('GDP per capita in $', color='red')
ax3.tick_params(axis='y', labelcolor='red')
# ... (previous code remains the same)

# Show legend for all lines outside the graph on the right side

# ... (rest of the code remains the same)



treatment_yearx = 2005
plt.axvline(x=treatment_yearx, color='red', linestyle='--', label=f'Juntus: {treatment_yearx}')



lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(0.1, 0.1 ))

lines = [line1, line2, line3]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(1.2, 1.2), borderaxespad=0.)






# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita), Gini Index, and GDP per Capita over Years in Peru (1990-2021)')
plt.tight_layout()
plt.legend()
plt.show()

# %%
import pandas as pd

# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
brazil_C02_data = pd.DataFrame({'Brazil': [228.603035, 235.896819, 239.335705, 250.505454, 258.807161,
                                            278.612488, 301.951476, 322.439560, 332.368130, 341.675538,
                                            364.751870, 365.659482, 365.512830, 365.861225, 382.382184,
                                            385.321073, 388.565459, 405.580573, 425.532830, 397.670767,
                                            450.435927, 470.163744, 506.651873, 532.936838, 559.341955,
                                            527.939104, 493.511293, 504.151474, 480.141718, 478.170180,
                                            441.369024, 489.857734]},
                               index=range(1990, 2022))

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df = pd.DataFrame({'Gini': brazil_gini_data.values}, index=brazil_gini_data.index)

# Reindex both DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
brazil_C02_data = brazil_C02_data.reindex(all_years)
gini_df = gini_df.reindex(all_years)

# Concatenate the DataFrames along the columns axis
combined = pd.concat([gini_df, brazil_C02_data], axis=1)

# Display the combined dataframe
print(combined)
# Out:
#       Gini      Brazil
# Year
# 1990  54.8  228.603035
# 1991  54.4  235.896819
# 1992  53.9  239.335705
# 1993  53.9  250.505454
# 1994  53.9  258.807161
# 1995  53.9  278.612488
# 1996  53.9  301.951476
# 1997  53.8  322.439560
# 1998  53.6  332.368130
# 1999  53.2  341.675538
# 2000  52.9  364.751870
# 2001  52.6  365.659482
# 2002  52.1  365.512830
# 2003  51.5  365.861225
# 2004  50.8  382.382184
# 2005  50.4  385.321073
# 2006  50.2  388.565459
# 2007  49.2  405.580573
# 2008  48.4  425.532830
# 2009  47.8  397.670767
# 2010  47.4  450.435927
# 2011  47.0  470.163744
# 2012  47.0  506.651873
# 2013  46.3  532.936838
# 2014  46.3  559.341955
# 2015  46.5  527.939104
# 2016  47.8  493.511293
# 2017  48.1  504.151474
# 2018  48.1  480.141718
# 2019  47.6  478.170180
# 2020  46.5  441.369024
# 2021  46.6  489.857734

# %%
brazil_gini_data = Gini.loc['Brazil']
print(brazil_gini_data)
# Out:
# year
# 1960    50.5
# 1961    50.6
# 1962    50.7
# 1963    50.8
# 1964    50.9
#         ...
# 2018    48.1
# 2019    47.6
# 2020    46.5
# 2021    46.6
# 2022     NaN
# Name: Brazil, Length: 63, dtype: float64

# %%
import pandas as pd

# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
brazil_C02_data = pd.DataFrame({'Brazil': [228.603035, 235.896819, 239.335705, 250.505454, 258.807161,
                                            278.612488, 301.951476, 322.439560, 332.368130, 341.675538,
                                            364.751870, 365.659482, 365.512830, 365.861225, 382.382184,
                                            385.321073, 388.565459, 405.580573, 425.532830, 397.670767,
                                            450.435927, 470.163744, 506.651873, 532.936838, 559.341955,
                                            527.939104, 493.511293, 504.151474, 480.141718, 478.170180,
                                            441.369024, 489.857734]},
                               index=range(1990, 2022))

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df = pd.DataFrame({'Gini': brazil_gini_data.values}, index=brazil_gini_data.index)

# Reindex both DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
brazil_C02_data = brazil_C02_data.reindex(all_years)
gini_df = gini_df.reindex(all_years)

# Concatenate the DataFrames along the columns axis
combined = pd.concat([gini_df, brazil_C02_data], axis=1)

# Display the combined dataframe
print(combined)
# Out:
#       Gini      Brazil
# Year
# 1990  54.8  228.603035
# 1991  54.4  235.896819
# 1992  53.9  239.335705
# 1993  53.9  250.505454
# 1994  53.9  258.807161
# 1995  53.9  278.612488
# 1996  53.9  301.951476
# 1997  53.8  322.439560
# 1998  53.6  332.368130
# 1999  53.2  341.675538
# 2000  52.9  364.751870
# 2001  52.6  365.659482
# 2002  52.1  365.512830
# 2003  51.5  365.861225
# 2004  50.8  382.382184
# 2005  50.4  385.321073
# 2006  50.2  388.565459
# 2007  49.2  405.580573
# 2008  48.4  425.532830
# 2009  47.8  397.670767
# 2010  47.4  450.435927
# 2011  47.0  470.163744
# 2012  47.0  506.651873
# 2013  46.3  532.936838
# 2014  46.3  559.341955
# 2015  46.5  527.939104
# 2016  47.8  493.511293
# 2017  48.1  504.151474
# 2018  48.1  480.141718
# 2019  47.6  478.170180
# 2020  46.5  441.369024
# 2021  46.6  489.857734

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined.index, combined['Brazil'], color='blue', marker='o', label='CO2 Emissions per Capita')
ax1.set_xlabel('Year')
ax1.set_ylabel('CO2 Emissions per Capita', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined.index, combined['Gini'], color='green', marker='o', label='Gini Index')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')

treatment_year1 = 2001
plt.axvline(x=treatment_year1, color='red', linestyle='--', label=f'Bolsa Escola: {treatment_year1}')

treatment_year2 = 2003
plt.axvline(x=treatment_year2, color='yellow', linestyle='--', label=f'Bolsa Família & start of L. I. Lula da Silvas presidency : {treatment_year2}')


treatment_year3 = 2011
plt.axvline(x=treatment_year3, color='green', linestyle='--', label=f'End of L. I. Lula da Silvas presidency: {treatment_year3}')


treatment_year4 = 2016
plt.axvline(x=treatment_year4, color='pink', linestyle='--', label=f'End of Dilma Rousseff presidency: {treatment_year4}')

treatment_year5 = 2018
plt.axvline(x=treatment_year5, color='orange', linestyle='--', label=f'End of Michel Temer presidency/beginning of Bolsonaro presidency: {treatment_year5}')

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('CO2 Emissions and Gini Index over Years (1990-2021)')
plt.legend()
plt.tight_layout()
plt.show()

# %%
gdp_per_capita=pd.read_csv("gdp-per-capita-worldbank.csv")
gdp_per_capita.head()
# Out:
#         Entity Code  Year  GDP per capita, PPP (constant 2017 international $)
# 0  Afghanistan  AFG  2002                                          1280.4631
# 1  Afghanistan  AFG  2003                                          1292.3335
# 2  Afghanistan  AFG  2004                                          1260.0605
# 3  Afghanistan  AFG  2005                                          1352.3207
# 4  Afghanistan  AFG  2006                                          1366.9932

# %%
brazil_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Brazil']
brazil_gdp_data.head()
# Out:
#      Entity Code  Year  GDP per capita, PPP (constant 2017 international $)
# 752  Brazil  BRA  1990                                          10401.843
# 753  Brazil  BRA  1991                                          10328.957
# 754  Brazil  BRA  1992                                          10103.788
# 755  Brazil  BRA  1993                                          10431.409
# 756  Brazil  BRA  1994                                          10867.751

# %%
plt.figure(figsize=(10, 6))
plt.plot(brazil_gdp_data['Year'], brazil_gdp_data['GDP per capita, PPP (constant 2017 international $)'], marker='o', linestyle='-', label='Brazil')


treatment_year1 = 2001
plt.axvline(x=treatment_year1, color='red', linestyle='--', label=f'Bolsa Escola: {treatment_year1}')

treatment_year2 = 2003
plt.axvline(x=treatment_year2, color='yellow', linestyle='--', label=f'Bolsa Família & start of L. I. Lula da Silvas presidency : {treatment_year2}')


treatment_year3 = 2011
plt.axvline(x=treatment_year3, color='green', linestyle='--', label=f'End of L. I. Lula da Silvas presidency: {treatment_year3}')


treatment_year4 = 2016
plt.axvline(x=treatment_year4, color='pink', linestyle='--', label=f'End of Dilma Rousseff presidency: {treatment_year4}')

treatment_year5 = 2018
plt.axvline(x=treatment_year5, color='orange', linestyle='--', label=f'End of Michel Temer presidency/beginning of Bolsonaro presidency: {treatment_year5}')

plt.title('GDP per Capita for Brazil Over the Years')
plt.xlabel('Year')
plt.ylabel('GDP per Capita (constant 2017 international $)')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import plotly
import plotly.express as px
import warnings
from statsmodels.formula.api import ols
from statsmodels.iolib.summary2 import summary_col
import matplotlib.pyplot as plt

# %%
C02_per_capita =pd.read_csv("co-emissions-per-capita.csv", usecols=['Entity', 'Code', 'Year', 'Annual CO₂ emissions (per capita)'])
C02_per_capita
# Out:
#             Entity Code  Year  Annual CO₂ emissions (per capita)
# 0      Afghanistan  AFG  1949                           0.001992
# 1      Afghanistan  AFG  1950                           0.011266
# 2      Afghanistan  AFG  1951                           0.012098
# 3      Afghanistan  AFG  1952                           0.011946
# 4      Afghanistan  AFG  1953                           0.013685
# ...            ...  ...   ...                                ...
# 26595     Zimbabwe  ZWE  2018                           0.711830
# 26596     Zimbabwe  ZWE  2019                           0.636645
# 26597     Zimbabwe  ZWE  2020                           0.500945
# 26598     Zimbabwe  ZWE  2021                           0.524972
# 26599     Zimbabwe  ZWE  2022                           0.542628
#
# [26600 rows x 4 columns]

# %%
C02_per_capita_brazil = C02_per_capita[C02_per_capita['Entity'] == 'Brazil']
C02_per_capita_brazil.head()
# Out:
#       Entity Code  Year  Annual CO₂ emissions (per capita)
# 3815  Brazil  BRA  1901                           0.113905
# 3816  Brazil  BRA  1902                           0.132818
# 3817  Brazil  BRA  1903                           0.126605
# 3818  Brazil  BRA  1904                           0.133064
# 3819  Brazil  BRA  1905                           0.139196

# %%
C02_per_capita_brazil_timeframe = C02_per_capita_brazil[(C02_per_capita_brazil['Year'] >= 1990) & (C02_per_capita_brazil['Year'] <= 2021)]

# Display the first few rows of the filtered data
print(C02_per_capita_brazil_timeframe)
# Out:
#       Entity Code  Year  Annual CO₂ emissions (per capita)
# 3904  Brazil  BRA  1990                           1.450887
# 3905  Brazil  BRA  1991                           1.496018
# 3906  Brazil  BRA  1992                           1.498395
# 3907  Brazil  BRA  1993                           1.541938
# 3908  Brazil  BRA  1994                           1.577843
# 3909  Brazil  BRA  1995                           1.643137
# 3910  Brazil  BRA  1996                           1.742448
# 3911  Brazil  BRA  1997                           1.821151
# 3912  Brazil  BRA  1998                           1.855469
# 3913  Brazil  BRA  1999                           1.886351
# 3914  Brazil  BRA  2000                           1.934246
# 3915  Brazil  BRA  2001                           1.942441
# 3916  Brazil  BRA  2002                           1.926925
# 3917  Brazil  BRA  2003                           1.887129
# 3918  Brazil  BRA  2004                           1.956637
# ...

# %%
C02_per_capita_Mexico_timeframe = C02_per_capita_Mexico[(C02_per_capita_Mexico ['Year'] >= 1990) & (C02_per_capita_Mexico ['Year'] <= 2021)]
C02_per_capita_Mexico_timeframe
# Out:
#        Entity Code  Year  Annual CO₂ emissions (per capita)
# 15545  Mexico  MEX  1990                           3.879598
# 15546  Mexico  MEX  1991                           3.960730
# 15547  Mexico  MEX  1992                           3.915376
# 15548  Mexico  MEX  1993                           3.901596
# 15549  Mexico  MEX  1994                           3.983983
# 15550  Mexico  MEX  1995                           3.680608
# 15551  Mexico  MEX  1996                           3.731603
# 15552  Mexico  MEX  1997                           3.892123
# 15553  Mexico  MEX  1998                           4.023621
# 15554  Mexico  MEX  1999                           4.009665
# 15555  Mexico  MEX  2000                           4.002362
# 15556  Mexico  MEX  2001                           4.102153
# 15557  Mexico  MEX  2002                           4.067756
# 15558  Mexico  MEX  2003                           4.258348
# 15559  Mexico  MEX  2004                           4.221425
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have datasets C02_per_capita_brazil_timeframe and C02_per_capita_Mexico_timeframe

# Plot for Brazil
plt.figure(figsize=(12, 6))
plt.plot(C02_per_capita_brazil_timeframe['Year'], C02_per_capita_brazil_timeframe['Annual CO₂ emissions (per capita)'], label='Brazil', marker='o')

# Plot for South Africa
plt.plot(C02_per_capita_Mexico_timeframe['Year'], C02_per_capita_Mexico_timeframe['Annual CO₂ emissions (per capita)'], label='Mexico', marker='o')

plt.yscale('log')  # Set y-axis to logarithmic scale

# Manually set y-axis tick locations based on the data
yticks = [1, 2, 5, 10]  # You can customize this list based on your data
ytick_labels = [str(tick) for tick in yticks]

plt.yticks(yticks, ytick_labels)

# Set y-axis limit to show only natural numbers from 0 to 10
plt.ylim([1, 10])

plt.xlabel('Year')
plt.ylabel('Annual CO₂ emissions (per capita)')
plt.title('CO₂ Emissions per Capita Over Time - Brazil and South Africa (log scale)')
plt.legend()
plt.show()

# %%
C02_per_capita_Egypt = C02_per_capita[C02_per_capita['Entity'] == 'Egypt']


C02_per_capita_Egypt_timeframe = C02_per_capita_Egypt[(C02_per_capita_Egypt['Year'] >= 1990) & (C02_per_capita_Egypt['Year'] <= 2021)]

# Display the first few rows of the filtered data
print(C02_per_capita_Egypt_timeframe)
# Out:
#      Entity Code  Year  Annual CO₂ emissions (per capita)
# 7172  Egypt  EGY  1990                           1.314655
# 7173  Egypt  EGY  1991                           1.318793
# 7174  Egypt  EGY  1992                           1.332572
# 7175  Egypt  EGY  1993                           1.503334
# 7176  Egypt  EGY  1994                           1.407751
# 7177  Egypt  EGY  1995                           1.542766
# 7178  Egypt  EGY  1996                           1.493946
# 7179  Egypt  EGY  1997                           1.667393
# 7180  Egypt  EGY  1998                           1.826633
# 7181  Egypt  EGY  1999                           1.834143
# 7182  Egypt  EGY  2000                           2.015319
# 7183  Egypt  EGY  2001                           1.752218
# 7184  Egypt  EGY  2002                           1.736100
# 7185  Egypt  EGY  2003                           1.973576
# 7186  Egypt  EGY  2004                           1.968149
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have datasets C02_per_capita_brazil_timeframe and C02_per_capita_South_Africa_timeframe

# Plot for Brazil
plt.figure(figsize=(12, 6))
plt.plot(C02_per_capita_brazil_timeframe['Year'], C02_per_capita_brazil_timeframe['Annual CO₂ emissions (per capita)'], label='Brazil', marker='o')

# Plot for South Africa
plt.plot(C02_per_capita_Egypt_timeframe['Year'], C02_per_capita_Egypt_timeframe['Annual CO₂ emissions (per capita)'], label='Egypt', marker='o')

# Set y-axis to logarithmic scale


plt.xlabel('Year')
plt.ylabel('Annual CO₂ emissions (per capita)')
plt.title('CO₂ Emissions per Capita Over Time - Brazil and Egypt')
plt.legend()
plt.show()

# %%
CO2_Brazil_Egypt = CO2_Brazil_Egypt.rename(columns={'Annual CO₂ emissions (per capita)': 'Annual_CO2_emissions_per_capita'})

# %%
# Assuming you have dataset C02_per_capita

# Subset the data to only include Brazil and Egypt for the years 1990 to 2021
CO2_Brazil_Egypt  = C02_per_capita[(C02_per_capita['Entity'].isin(['Brazil', 'Egypt'])) & (C02_per_capita['Year'] >= 1990) & (C02_per_capita['Year'] <= 2021)]

# Plot the data using Plotly Express
fig = px.line(CO2_Brazil_Egypt , x='Year', y='Annual CO₂ emissions (per capita)', color='Entity', title="Annual CO₂ emissions (per capita) Brazil & Egypt")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np

# Assuming CO2_Brazil_Egypt is your DataFrame
CO2_Brazil_Egypt['Year'] = pd.to_numeric(CO2_Brazil_Egypt['Year'], errors='coerce')  # Convert 'Year' to numeric, handle errors by setting invalid values to NaN

CO2_Brazil_Egypt['post'] = np.where(CO2_Brazil_Egypt['Year'] >= 2001, 1, 0)  # Compare with numeric value 2001
CO2_Brazil_Egypt['treatment'] = np.where(CO2_Brazil_Egypt['Entity'] == 'Brazil', 1, 0)
CO2_Brazil_Egypt['post_treatment'] = CO2_Brazil_Egypt['post'] * CO2_Brazil_Egypt['treatment']

print(CO2_Brazil_Egypt)
# Out:
#       Entity Code  Year  Annual CO₂ emissions (per capita)  post  treatment  \
# 3904  Brazil  BRA  1990                           1.450887     0          1
# 3905  Brazil  BRA  1991                           1.496018     0          1
# 3906  Brazil  BRA  1992                           1.498395     0          1
# 3907  Brazil  BRA  1993                           1.541938     0          1
# 3908  Brazil  BRA  1994                           1.577843     0          1
# ...      ...  ...   ...                                ...   ...        ...
# 7199   Egypt  EGY  2017                           2.555380     1          0
# 7200   Egypt  EGY  2018                           2.351129     1          0
# 7201   Egypt  EGY  2019                           2.425141     1          0
# 7202   Egypt  EGY  2020                           2.118249     1          0
# 7203   Egypt  EGY  2021                           2.259559     1          0
#
#       post_treatment
# 3904               0
# ...

# %%
from statsmodels.formula.api import ols
import numpy as np
import pandas as pd
from statsmodels.formula.api import ols

# %%
CO2_Brazil_Egypt = CO2_Brazil_Egypt.rename(columns={'Annual CO₂ emissions (per capita)': 'Annual_CO2_emissions_per_capita'})

# %%
CO2_Brazil_Egypt_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', data=CO2_Brazil_Egypt).fit()
print(CO2_Brazil_Egypt_model.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Annual_CO2_emissions_per_capita   R-squared:                       0.628
# Model:                                         OLS   Adj. R-squared:                  0.609
# Method:                              Least Squares   F-statistic:                     33.77
# Date:                             Mon, 08 Jan 2024   Prob (F-statistic):           6.52e-13
# Time:                                     18:25:02   Log-Likelihood:                 5.4750
# No. Observations:                               64   AIC:                            -2.950
# Df Residuals:                                   60   BIC:                             5.686
# Df Model:                                        3
# Covariance Type:                         nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
models = []  # create empty list to store the models
names = []  # create empty list to store the names of the models

for window in range(1, 10):  # loop through years
    did = CO2_Brazil_Egypt [(CO2_Brazil_Egypt ['Year'] >= 2001 - window) & (CO2_Brazil_Egypt['Year'] <= 2001 + window)]  # subset the data within the window of interest around 2005
    did['post'] = np.where(did['Year'] >= 2001, 1, 0)  # create a dummy variable indicating the period after 1997
    did['treatment'] = np.where(did['Entity'] == 'Brazil', 1, 0)  # create a dummy variable for treatment
    did['post_treatment'] = did['post'] * did['treatment']  # create an interaction term between the post and treatment variables

    did_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', did).fit()  # run the difference in difference model

    models.append(did_model)  # append the model to the list of models
    names.append('± ' + str(window) + ' Year')  # append the name of the model to the list of names

table = summary_col(  # create a regression table
    models,  # pass the models to the summary_col function
    stars=True,  # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f',  # set the decimal places to 3
    model_names=names,  # set the names of the model
    info_dict={"N": lambda x: "{0:d}".format(int(x.nobs))})  # add the number of observations to the table

print(table)  # print the table
# Out:
# ...
#                 ± 1 Year ± 2 Year ± 3 Year ± 4 Year ± 5 Year ± 6 Year ± 7 Year ± 8 Year ± 9 Year
# ------------------------------------------------------------------------------------------------
# Intercept      2.015***  1.925*** 1.892*** 1.836*** 1.767*** 1.730*** 1.684*** 1.661*** 1.625***
#                (0.011)   (0.067)  (0.052)  (0.057)  (0.064)  (0.065)  (0.067)  (0.065)  (0.065)
# post           -0.271*** -0.104   -0.035   0.076    0.196**  0.281*** 0.370*** 0.433*** 0.493***
#                (0.014)   (0.087)  (0.068)  (0.076)  (0.087)  (0.088)  (0.092)  (0.090)  (0.089)
# treatment      -0.081**  -0.014   -0.000   0.038    0.080    0.084    0.096    0.089    0.097
#                (0.016)   (0.095)  (0.073)  (0.080)  (0.091)  (0.091)  (0.095)  (0.092)  (0.092)
# post_treatment 0.272***  0.113    0.071    -0.017   -0.108   -0.143   -0.175   -0.204   -0.211
#                (0.019)   (0.123)  (0.097)  (0.108)  (0.123)  (0.125)  (0.130)  (0.127)  (0.126)
# ...

# %%
# Assuming you have dataset C02_per_capita

# Subset the data to only include Brazil and Egypt for the years 1990 to 2021
CO2_Mexico_Mauritius  = C02_per_capita[(C02_per_capita['Entity'].isin(['Mexico', 'Mauritius'])) & (C02_per_capita['Year'] >= 1990) & (C02_per_capita['Year'] <= 2021)]

# Plot the data using Plotly Express
fig = px.line(CO2_Mexico_Mauritius , x='Year', y='Annual CO₂ emissions (per capita)', color='Entity', title="Annual CO₂ emissions (per capita) Mexico & Mauritius")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
CO2_Mexico_Mauritius = CO2_Mexico_Mauritius.rename(columns={'Annual CO₂ emissions (per capita)': 'Annual_CO2_emissions_per_capita'})

# %%
import numpy as np

# Assuming CO2_Brazil_Egypt is your DataFrame
CO2_Mexico_Mauritius['Year'] = pd.to_numeric(CO2_Mexico_Mauritius['Year'], errors='coerce')  # Convert 'Year' to numeric, handle errors by setting invalid values to NaN

CO2_Mexico_Mauritius['post'] = np.where(CO2_Mexico_Mauritius['Year'] >= 1997, 1, 0)  # Compare with numeric value 2001
CO2_Mexico_Mauritius['treatment'] = np.where(CO2_Mexico_Mauritius['Entity'] == 'Mexico', 1, 0)
CO2_Mexico_Mauritius['post_treatment'] = CO2_Mexico_Mauritius['post'] * CO2_Mexico_Mauritius['treatment']

print(CO2_Mexico_Mauritius)
# Out:
#           Entity Code  Year  Annual_CO2_emissions_per_capita  post  treatment  \
# 15413  Mauritius  MUS  1990                         1.340862     0          0
# 15414  Mauritius  MUS  1991                         1.376986     0          0
# 15415  Mauritius  MUS  1992                         1.526231     0          0
# 15416  Mauritius  MUS  1993                         1.564845     0          0
# 15417  Mauritius  MUS  1994                         1.414925     0          0
# ...          ...  ...   ...                              ...   ...        ...
# 15572     Mexico  MEX  2017                         3.790490     1          1
# 15573     Mexico  MEX  2018                         3.792204     1          1
# 15574     Mexico  MEX  2019                         3.744022     1          1
# 15575     Mexico  MEX  2020                         3.510278     1          1
# 15576     Mexico  MEX  2021                         3.699861     1          1
#
#        post_treatment
# ...

# %%
CO2_Mexico_Mauritius_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', data=CO2_Mexico_Mauritius).fit()
print(CO2_Mexico_Mauritius_model.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Annual_CO2_emissions_per_capita   R-squared:                       0.851
# Model:                                         OLS   Adj. R-squared:                  0.843
# Method:                              Least Squares   F-statistic:                     114.2
# Date:                             Mon, 08 Jan 2024   Prob (F-statistic):           9.19e-25
# Time:                                     18:25:03   Log-Likelihood:                -24.257
# No. Observations:                               64   AIC:                             56.51
# Df Residuals:                                   60   BIC:                             65.15
# Df Model:                                        3
# Covariance Type:                         nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %%
import pandas as pd
import numpy as np
from statsmodels.formula.api import ols
from statsmodels.iolib.summary2 import summary_col

# Assuming CO2_Mexico_Mauritius is your DataFrame
models = []  # create empty list to store the models
names = []  # create empty list to store the names of the models

for window in range(1, 10):  # loop through years
    did = CO2_Mexico_Mauritius[(CO2_Mexico_Mauritius['Year'] >= 1997 - window) & (CO2_Mexico_Mauritius['Year'] <= 1997 + window)]  # subset the data within the window of interest around 2005
    did['post'] = np.where(did['Year'] >= 1997, 1, 0)  # create a dummy variable indicating the period after 1997
    did['treatment'] = np.where(did['Entity'] == 'Mexico', 1, 0)  # create a dummy variable for treatment
    did['post_treatment'] = did['post'] * did['treatment']  # create an interaction term between the post and treatment variables

    did_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', did).fit()  # run the difference in difference model

    models.append(did_model)  # append the model to the list of models
    names.append('± ' + str(window) + ' Year')  # append the name of the model to the list of names

table = summary_col(  # create a regression table
    models,  # pass the models to the summary_col function
    stars=True,  # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f',  # set the decimal places to 3
    model_names=names,  # set the names of the model
    info_dict={"N": lambda x: "{0:d}".format(int(x.nobs))})  # add the number of observations to the table

print(table)  # print the table
# Out:
# ...
#                ± 1 Year ± 2 Year ± 3 Year ± 4 Year ± 5 Year  ± 6 Year  ± 7 Year  ± 8 Year  ± 9 Year
# ---------------------------------------------------------------------------------------------------
# Intercept      1.662*** 1.619*** 1.551*** 1.555*** 1.549*** 1.520***  1.495***  1.495***  1.495***
#                (0.092)  (0.076)  (0.092)  (0.085)  (0.075)  (0.074)   (0.070)   (0.077)   (0.088)
# post           0.088    0.219*   0.380**  0.458*** 0.517*** 0.603***  0.672***  0.722***  0.787***
#                (0.113)  (0.098)  (0.122)  (0.114)  (0.101)  (0.101)   (0.095)   (0.102)   (0.115)
# treatment      2.069*** 2.087*** 2.248*** 2.270*** 2.294*** 2.342***  2.370***  2.370***  2.370***
#                (0.130)  (0.108)  (0.130)  (0.120)  (0.106)  (0.105)   (0.098)   (0.109)   (0.125)
# post_treatment 0.138    0.050    -0.197   -0.276   -0.344** -0.414*** -0.464*** -0.478*** -0.510***
# ...

# %% [markdown]
# Great! Now, let's interpret the updated regression results for the model related to Mexico and Mauritius:
#
# Dependent Variable: Annual_CO2_emissions_per_capita
# R-squared and Adjusted R-squared:
# The R-squared is 0.851, indicating that approximately 85.1% of the variability in the dependent variable is explained by the model.
# The Adjusted R-squared is 0.843, which adjusts the R-squared for the number of predictors in the model.
# F-statistic and Prob (F-statistic):
# The F-statistic is 114.2, suggesting that the overall model is statistically significant.
# The p-value associated with the F-statistic is very small (9.19e-25), indicating strong evidence against the null hypothesis that all coefficients are zero.
# Coefficients:
# Intercept: The intercept is 1.4946, representing the estimated value of the dependent variable when all predictors are zero.
# post (Effect after a certain year): The coefficient for 'post' is 1.3164, and it is statistically significant (p-value < 0.001). This suggests a statistically significant increase in 'Annual_CO2_emissions_per_capita' after the specified year compared to before.
# treatment (Effect of the treatment): The coefficient for 'treatment' is 2.3702, and it is statistically significant (p-value < 0.001). This suggests a statistically significant difference in 'Annual_CO2_emissions_per_capita' between the treatment and control groups.
# post_treatment (Interaction effect): The coefficient for 'post_treatment' is -1.1151, and it is statistically significant (p-value < 0.001). This suggests a statistically significant difference in the effect of 'post' between the treatment and control groups.
# Omnibus, Durbin-Watson, Jarque-Bera, Skew, and Kurtosis:
# The Omnibus test suggests a departure from normality.
# The Durbin-Watson statistic is low (0.371), indicating potential issues with autocorrelation.
# The Jarque-Bera test p-value (0.00471) suggests a departure from normality, and it is statistically significant.
# Skewness is -0.783, indicating a leftward skew.
# Kurtosis is 4.253, indicating a distribution with heavier tails than a normal distribution.
# Overall, the model seems to have a good fit, and the coefficients are statistically significant. However, the low Durbin-Watson statistic suggests potential issues with autocorrelation, and the departure from normality indicated by the Omnibus and Jarque-Bera tests should be considered in the interpretation.
#
# If you have any specific questions or if there's anything else you'd like to explore, feel free to let me know!

# %%
# Assuming you have dataset C02_per_capita

# Subset the data to only include Brazil and Egypt for the years 1990 to 2021
CO2_Peru_Costarica  = C02_per_capita[(C02_per_capita['Entity'].isin(['Peru', 'Costa Rica'])) & (C02_per_capita['Year'] >= 1990) & (C02_per_capita['Year'] <= 2021)]

# Plot the data using Plotly Express
fig = px.line(CO2_Peru_Costarica , x='Year', y='Annual CO₂ emissions (per capita)', color='Entity', title="Annual CO₂ emissions (per capita) Peru & Costa Rica")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
CO2_Peru_Costarica = CO2_Peru_Costarica.rename(columns={'Annual CO₂ emissions (per capita)': 'Annual_CO2_emissions_per_capita'})

# %%
CO2_Peru_Costarica['Year'] = pd.to_numeric(CO2_Peru_Costarica['Year'], errors='coerce')  # Convert 'Year' to numeric, handle errors by setting invalid values to NaN

CO2_Peru_Costarica['post'] = np.where(CO2_Peru_Costarica['Year'] >= 2005, 1, 0)  # Compare with numeric value 2001
CO2_Peru_Costarica['treatment'] = np.where(CO2_Peru_Costarica['Entity'] == 'Peru', 1, 0)
CO2_Peru_Costarica['post_treatment'] = CO2_Peru_Costarica['post'] * CO2_Peru_Costarica['treatment']

print(CO2_Peru_Costarica)
# Out:
#            Entity Code  Year  Annual_CO2_emissions_per_capita  post  \
# 5675   Costa Rica  CRI  1990                         0.922349     0
# 5676   Costa Rica  CRI  1991                         1.014970     0
# 5677   Costa Rica  CRI  1992                         1.126409     0
# 5678   Costa Rica  CRI  1993                         1.142573     0
# 5679   Costa Rica  CRI  1994                         1.490288     0
# ...           ...  ...   ...                              ...   ...
# 19063        Peru  PER  2017                         1.735741     1
# 19064        Peru  PER  2018                         1.734205     1
# 19065        Peru  PER  2019                         1.778074     1
# 19066        Peru  PER  2020                         1.410164     1
# 19067        Peru  PER  2021                         1.674903     1
#
#        treatment  post_treatment
# 5675           0               0
# 5676           0               0
# 5677           0               0
# ...

# %%
CO2_Peru_Costarica_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', data=CO2_Peru_Costarica).fit()
print(CO2_Peru_Costarica_model.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Annual_CO2_emissions_per_capita   R-squared:                       0.637
# Model:                                         OLS   Adj. R-squared:                  0.619
# Method:                              Least Squares   F-statistic:                     35.13
# Date:                             Mon, 08 Jan 2024   Prob (F-statistic):           3.11e-13
# Time:                                     18:25:03   Log-Likelihood:                 24.912
# No. Observations:                               64   AIC:                            -41.82
# Df Residuals:                                   60   BIC:                            -33.19
# Df Model:                                        3
# Covariance Type:                         nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# ependent Variable: Annual_CO2_emissions_per_capita
# R-squared and Adjusted R-squared:
# The R-squared is 0.637, indicating that approximately 63.7% of the variability in the dependent variable is explained by the model.
# The Adjusted R-squared is 0.619, which adjusts the R-squared for the number of predictors in the model.
# F-statistic and Prob (F-statistic):
# The F-statistic is 35.13, suggesting that the overall model is statistically significant.
# The p-value associated with the F-statistic is very small (3.11e-13), indicating strong evidence against the null hypothesis that all coefficients are zero.
# Coefficients:
# Intercept: The intercept is 1.3233, representing the estimated value of the dependent variable when all predictors are zero.
# post (Effect after a certain year): The coefficient for 'post' is 0.2621, and it is statistically significant (p-value < 0.001). This suggests a statistically significant increase in 'Annual_CO2_emissions_per_capita' after the specified year compared to before.
# treatment (Effect of the treatment): The coefficient for 'treatment' is -0.3229, and it is statistically significant (p-value < 0.001). This indicates a statistically significant difference in 'Annual_CO2_emissions_per_capita' between the treatment (Peru) and control (Costa Rica) groups.
# post_treatment (Interaction effect): The coefficient for 'post_treatment' is 0.2059, and it is statistically significant (p-value = 0.018). This suggests that there is a significant difference in the effect of 'post' between the treatment and control groups.
# Omnibus, Durbin-Watson, Jarque-Bera, Skew, and Kurtosis:
# The Omnibus test suggests no strong departure from normality.
# The Durbin-Watson statistic is 0.594, indicating potential issues with autocorrelation.
# The Jarque-Bera test p-value (0.0956) suggests no strong departure from normality, and it is not statistically significant.
# Skewness is -0.589, indicating a slight leftward skew.
# Kurtosis is 3.610, indicating a distribution with somewhat heavier tails than a normal distribution.
# In summary, the model has a good fit, and all coefficients are statistically significant. The treatment effect ('treatment') has a negative coefficient, suggesting a significant decrease in 'Annual_CO2_emissions_per_capita' in Peru compared to Costa Rica. The interaction effect ('post_treatment') indicates a significant difference in the effect of 'post' between the treatment and control groups.
#
# If you have any further questions or if there's anything specific you'd like to explore, feel free to let me know!

# %%
# Assuming CO2_Mexico_Mauritius is your DataFrame
models = []  # create empty list to store the models
names = []  # create empty list to store the names of the models

for window in range(1, 10):  # loop through years
    did = CO2_Peru_Costarica [(CO2_Peru_Costarica ['Year'] >= 2005 - window) & (CO2_Peru_Costarica['Year'] <= 2005 + window)]  # subset the data within the window of interest around 2005
    did['post'] = np.where(did['Year'] >= 2005, 1, 0)  # create a dummy variable indicating the period after 1997
    did['treatment'] = np.where(did['Entity'] == 'Peru', 1, 0)  # create a dummy variable for treatment
    did['post_treatment'] = did['post'] * did['treatment']  # create an interaction term between the post and treatment variables

    did_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', did).fit()  # run the difference in difference model

    models.append(did_model)  # append the model to the list of models
    names.append('± ' + str(window) + ' Year')  # append the name of the model to the list of names

table = summary_col(  # create a regression table
    models,  # pass the models to the summary_col function
    stars=True,  # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f',  # set the decimal places to 3
    model_names=names,  # set the names of the model
    info_dict={"N": lambda x: "{0:d}".format(int(x.nobs))})  # add the number of observations to the table

print(table)  # print the table
# Out:
# ...
#                ± 1 Year  ± 2 Year  ± 3 Year  ± 4 Year  ± 5 Year  ± 6 Year  ± 7 Year  ± 8 Year  ± 9 Year
# -------------------------------------------------------------------------------------------------------
# Intercept      1.609*** 1.590***  1.565***  1.523***  1.490***  1.474***  1.459***  1.441***  1.423***
#                (0.047)  (0.071)   (0.055)   (0.053)   (0.054)   (0.051)   (0.049)   (0.045)   (0.044)
# post           -0.030   0.060     0.116     0.161**   0.184**   0.184**   0.184**   0.196***  0.210***
#                (0.058)  (0.092)   (0.073)   (0.071)   (0.073)   (0.069)   (0.067)   (0.062)   (0.061)
# treatment      -0.593** -0.636*** -0.618*** -0.578*** -0.518*** -0.477*** -0.449*** -0.420*** -0.406***
#                (0.066)  (0.101)   (0.078)   (0.075)   (0.076)   (0.072)   (0.069)   (0.064)   (0.063)
# post_treatment 0.049    0.075     0.061     0.065     0.063     0.067     0.091     0.084     0.106
# ...

# %%
# Assuming you have dataset C02_per_capita

# Subset the data to only include Brazil and Egypt for the years 1990 to 2021
CO2_Germany_belgium  = C02_per_capita[(C02_per_capita['Entity'].isin(['Germany', 'Belgium'])) & (C02_per_capita['Year'] >= 1990) & (C02_per_capita['Year'] <= 2021)]

# Plot the data using Plotly Express
fig = px.line(CO2_Germany_belgium, x='Year', y='Annual CO₂ emissions (per capita)', color='Entity', title="Annual CO₂ emissions (per capita) Germany & Belgium")

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
CO2_Germany_belgium = CO2_Germany_belgium.rename(columns={'Annual CO₂ emissions (per capita)': 'Annual_CO2_emissions_per_capita'})

# %%
CO2_Germany_belgium['Year'] = pd.to_numeric(CO2_Germany_belgium['Year'], errors='coerce')  # Convert 'Year' to numeric, handle errors by setting invalid values to NaN

CO2_Germany_belgium['post'] = np.where(CO2_Germany_belgium['Year'] >= 2005, 1, 0)  # Compare with numeric value 2001
CO2_Germany_belgium['treatment'] = np.where(CO2_Germany_belgium['Entity'] == 'Germany', 1, 0)
CO2_Germany_belgium['post_treatment'] = CO2_Germany_belgium['post'] * CO2_Germany_belgium['treatment']

print(CO2_Germany_belgium)
# Out:
#        Entity Code  Year  Annual_CO2_emissions_per_capita  post  treatment  \
# 2989  Belgium  BEL  1990                        12.078118     0          0
# 2990  Belgium  BEL  1991                        12.352231     0          0
# 2991  Belgium  BEL  1992                        12.228726     0          0
# 2992  Belgium  BEL  1993                        12.089510     0          0
# 2993  Belgium  BEL  1994                        12.393930     0          0
# ...       ...  ...   ...                              ...   ...        ...
# 9969  Germany  DEU  2017                         9.512761     1          1
# 9970  Germany  DEU  2018                         9.105443     1          1
# 9971  Germany  DEU  2019                         8.508805     1          1
# 9972  Germany  DEU  2020                         7.767432     1          1
# 9973  Germany  DEU  2021                         8.138241     1          1
#
#       post_treatment
# 2989               0
# 2990               0
# ...

# %%
CO2_Germany_belgium_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', data=CO2_Germany_belgium).fit()
print(CO2_Germany_belgium_model.summary())
# Out:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Annual_CO2_emissions_per_capita   R-squared:                       0.666
# Model:                                         OLS   Adj. R-squared:                  0.650
# Method:                              Least Squares   F-statistic:                     39.93
# Date:                             Mon, 08 Jan 2024   Prob (F-statistic):           2.59e-14
# Time:                                     18:25:04   Log-Likelihood:                -79.554
# No. Observations:                               64   AIC:                             167.1
# Df Residuals:                                   60   BIC:                             175.7
# Df Model:                                        3
# Covariance Type:                         nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# ...

# %% [markdown]
# R-squared and Adjusted R-squared:
#
# The R-squared is 0.666, indicating that approximately 66.6% of the variability in the dependent variable is explained by the model.
# The Adjusted R-squared is 0.650, which adjusts the R-squared for the number of predictors in the model.
# F-statistic and Prob (F-statistic):
#
# The F-statistic is 39.93, suggesting that the overall model is statistically significant.
# The p-value associated with the F-statistic is very small (2.59e-14), indicating strong evidence against the null hypothesis that all coefficients are zero.
# Coefficients:
#
# Intercept: The intercept is 12.3375, representing the estimated value of the dependent variable when all predictors are zero.
# post (Effect after a certain year): The coefficient for 'post' is -2.7218, and it is statistically significant (p-value < 0.001). This suggests a statistically significant decrease in 'Annual_CO2_emissions_per_capita' after the specified year compared to before.
# treatment (Effect of the treatment): The coefficient for 'treatment' is -0.7330, and it is statistically significant (p-value = 0.024). This indicates a statistically significant difference in 'Annual_CO2_emissions_per_capita' between the treatment (Germany) and control (Belgium) groups.
# post_treatment (Interaction effect): The coefficient for 'post_treatment' is 0.8031, and it is marginally significant (p-value = 0.069). This suggests that there is a potential difference in the effect of 'post' between the treatment and control groups.
# Omnibus, Durbin-Watson, Jarque-Bera, Skew, and Kurtosis:
#
# The Omnibus test suggests no strong departure from normality.
# The Durbin-Watson statistic is 0.605, indicating potential issues with autocorrelation.
# The Jarque-Bera test p-value (0.222) suggests no strong departure from normality, and it is not statistically significant.
# Skewness is 0.422, indicating a slight rightward skew.
# Kurtosis is 3.645, indicating a distribution with somewhat heavier tails than a normal distribution.
# In summary, the model has a good fit, and the treatment effect ('treatment') has a negative coefficient, suggesting a significant decrease in 'Annual_CO2_emissions_per_capita' in Germany compared to Belgium. The interaction effect ('post_treatment') indicates a potential difference in the effect of 'post' between the treatment and control groups, although this is marginally significant.
#
# If you have any further questions or if there's anything specific you'd like to explore, feel free to let me know!

# %%
models = []  # create empty list to store the models
names = []  # create empty list to store the names of the models

for window in range(1, 10):  # loop through years
    did = CO2_Germany_belgium [(CO2_Germany_belgium ['Year'] >= 2005 - window) & (CO2_Germany_belgium['Year'] <= 2005 + window)]  # subset the data within the window of interest around 2005
    did['post'] = np.where(did['Year'] >= 2005, 1, 0)  # create a dummy variable indicating the period after 1997
    did['treatment'] = np.where(did['Entity'] == 'Germany', 1, 0)  # create a dummy variable for treatment
    did['post_treatment'] = did['post'] * did['treatment']  # create an interaction term between the post and treatment variables

    did_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment', did).fit()  # run the difference in difference model

    models.append(did_model)  # append the model to the list of models
    names.append('± ' + str(window) + ' Year')  # append the name of the model to the list of names

table = summary_col(  # create a regression table
    models,  # pass the models to the summary_col function
    stars=True,  # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f',  # set the decimal places to 3
    model_names=names,  # set the names of the model
    info_dict={"N": lambda x: "{0:d}".format(int(x.nobs))})  # add the number of observations to the table

print(table)  # print the table
# Out:
# ...
#                 ± 1 Year  ± 2 Year  ± 3 Year  ± 4 Year  ± 5 Year  ± 6 Year  ± 7 Year  ± 8 Year  ± 9 Year
# --------------------------------------------------------------------------------------------------------
# Intercept      12.315*** 12.322*** 12.298*** 12.281*** 12.294*** 12.277*** 12.349*** 12.332*** 12.383***
#                (0.142)   (0.152)   (0.123)   (0.236)   (0.199)   (0.209)   (0.215)   (0.208)   (0.217)
# post           -0.490    -0.669**  -0.758*** -1.053*** -1.182*** -1.383*** -1.656*** -1.799*** -2.035***
#                (0.174)   (0.197)   (0.162)   (0.316)   (0.269)   (0.284)   (0.294)   (0.286)   (0.299)
# treatment      -1.417**  -1.342*** -1.299*** -1.225*** -1.244*** -1.240*** -1.270*** -1.208*** -1.183***
#                (0.201)   (0.215)   (0.173)   (0.333)   (0.281)   (0.295)   (0.304)   (0.294)   (0.306)
# post_treatment 0.326     0.336     0.369     0.425     0.526     0.671     0.858**   0.948**   1.052**
# ...

# %%
# !pip install linearmodels

# %%
for window in range(1, 10):
    CO2_Germany_belgium = C02_per_capita[
        (C02_per_capita['Entity'].isin(['Germany', 'Belgium'])) &
        (C02_per_capita['Year'] >= (2005 - window)) &
        (C02_per_capita['Year'] <= (2014 + window))]  # subset the data within the window of interest around 2014

    print(f"Window {window} - Data count before filtering: {len(C02_per_capita)}")
    print(f"Window {window} - Data count after filtering: {len(CO2_Germany_belgium)}")

    CO2_Germany_belgium['post'] = np.where(CO2_Germany_belgium['Year'] >= 2005, 1, 0)  # create a dummy variable indicating the period after the minimum wage increase
    CO2_Germany_belgium['treatment'] = np.where(CO2_Germany_belgium['Entity'] == 'Germany', 1, 0)  # create a dummy variable for treatment
    CO2_Germany_belgium['post_treatment'] = CO2_Germany_belgium['post'] * CO2_Germany_belgium['treatment']  # create an interaction term between the post and treatment variables
    CO2_Germany_belgium_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment',
                                    data=CO2_Germany_belgium).fit()  # run the difference in difference model

    print(f"Window {window} - Model Summary:")
    print(CO2_Germany_belgium_model.summary())

    models.append(CO2_Germany_belgium_model)  # append the model to the list of models
    names.append('± ' + str(window) + ' Year')  # append the name of the model to the list of names

table = summary_col(  # create a regression table
    models,  # pass the models to the summary_col function
    stars=True,  # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f',  # set the decimal places to 3
    model_names=names,  # set the names of the model
    info_dict={"N": lambda x: "{0:d}".format(int(x.nobs))})  # add the number of observations to the table

print(table)  # print the table
# Out:
# Window 1 - Data count before filtering: 26600
# Window 1 - Data count after filtering: 24
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     168         code = compile(expr, source_name, "eval", self.flags, False)
# --> 169         return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                             + self._namespaces))
#
# <string> in <module>
#
# NameError: name 'Annual_CO2_emissions_per_capita' is not defined
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for window in range(1, 10):
    CO2_Germany_belgium = C02_per_capita[
        (C02_per_capita['Year'] >= (2005 - window)) &
        (C02_per_capita['Year'] <= (2014 + window)) &
        C02_per_capita['Entity'].isin(['Germany', 'Belgium'])
    ]  # subset the data within the window of interest around 2014

    print(f"Window {window} - Unique 'Year' values in CO2_Germany_belgium: {CO2_Germany_belgium['Year'].unique()}")
    print(f"Window {window} - Unique 'Entity' values in CO2_Germany_belgium: {CO2_Germany_belgium['Entity'].unique()}")

    CO2_Germany_belgium['post'] = np.where(CO2_Germany_belgium['Year'] >= 2005, 1, 0)  # create a dummy variable indicating the period after the minimum wage increase
    CO2_Germany_belgium['treatment'] = np.where(CO2_Germany_belgium['Entity'] == 'Germany', 1, 0)  # create a dummy variable for treatment
    CO2_Germany_belgium['post_treatment'] = CO2_Germany_belgium['post'] * CO2_Germany_belgium['treatment']  # create an interaction term between the post and treatment variables

    print(f"Window {window} - Unique 'post' values in CO2_Germany_belgium: {CO2_Germany_belgium['post'].unique()}")
    print(f"Window {window} - Unique 'treatment' values in CO2_Germany_belgium: {CO2_Germany_belgium['treatment'].unique()}")

    CO2_Germany_belgium_model = ols('Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment',
                                    data=CO2_Germany_belgium).fit()  # run the difference in difference model

    print(f"Window {window} - Model Summary:")
    print(CO2_Germany_belgium_model.summary())

    models.append(CO2_Germany_belgium_model)  # append the model to the list of models
    names.append('± ' + str(window) + ' Year')  # append the name of the model to the list of names

table = summary_col(  # create a regression table
    models,  # pass the models to the summary_col function
    stars=True,  # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f',  # set the decimal places to 3
    model_names=names,  # set the names of the model
    info_dict={"N": lambda x: "{0:d}".format(int(x.nobs))})  # add the number of observations to the table

print(table)  # print the table
# Out:
# Window 1 - Unique 'Year' values in CO2_Germany_belgium: [2004 2005 2006 2007 2008 2009 2010 2011 2012 2013 2014 2015]
# Window 1 - Unique 'Entity' values in CO2_Germany_belgium: ['Belgium' 'Germany']
# Window 1 - Unique 'post' values in CO2_Germany_belgium: [0 1]
# Window 1 - Unique 'treatment' values in CO2_Germany_belgium: [0 1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/patsy/compat.py in call_and_wrap_exc(msg, origin, f, *args, **kwargs)
#      35     try:
# ---> 36         return f(*args, **kwargs)
#      37     except Exception as e:
#
# /usr/local/lib/python3.10/dist-packages/patsy/eval.py in eval(self, expr, source_name, inner_namespace)
#     168         code = compile(expr, source_name, "eval", self.flags, False)
# --> 169         return eval(code, {}, VarLookupDict([inner_namespace]
# ...

# %%
print(CO2_Germany_belgium.dtypes)
# Out:
# Entity                                object
# Code                                  object
# Year                                   int64
# Annual CO₂ emissions (per capita)    float64
# post                                   int64
# treatment                              int64
# post_treatment                         int64
# dtype: object

# %%
# !pip install linearmodels

# %%
CO2_Germany_belgium = CO2_Germany_belgium.rename(columns={'Annual CO₂ emissions (per capita)': 'Annual_CO2_emissions_per_capita'})

# %%
from linearmodels.panel import PanelOLS
import statsmodels.formula.api as smf
from statsmodels.iolib.summary2 import summary_col
import pandas as pd
import numpy as np

# Assume you have C02_per_capita DataFrame with the required structure
# Extend the data for the years 1990 to 2021
data_extended = {'Entity': [], 'Year': [], 'Annual_CO2_emissions_per_capita': []}

for year in range(1990, 2022):
    for entity in ['Germany', 'Belgium']:
        data_extended['Entity'].append(entity)
        data_extended['Year'].append(year)
        # Replace 0 with the actual data for each year
        data_extended['Annual_CO2_emissions_per_capita'].append(0 if year < 1990 or year > 1992 else data['Annual_CO2_emissions_per_capita'][year - 1990])

# Create a DataFrame
C02_per_capita = pd.DataFrame(data_extended)

models = []  # create an empty list to store the models
names = []  # create an empty list to store the names of the models

for window in range(1, 10):  # loop through years from 1 to 10
    CO2_Germany_belgium = C02_per_capita[
        (C02_per_capita['Year'] >= 2005 - window) & (C02_per_capita['Year'] <= 2006 + window) &
        (C02_per_capita['Entity'].isin(['Germany', 'Belgium']))
    ]

    # create dummy variables
    CO2_Germany_belgium['post'] = np.where(CO2_Germany_belgium['Year'] >= 2005, 1, 0)
    CO2_Germany_belgium['treatment'] = np.where(CO2_Germany_belgium['Entity'] == 'Germany', 1, 0)
    CO2_Germany_belgium['post_treatment'] = CO2_Germany_belgium['post'] * CO2_Germany_belgium['treatment']

    # run the difference in difference model
    CO2_Germany_belgium_model = smf.ols(
        'Annual_CO2_emissions_per_capita ~ post + treatment + post_treatment',
        data=CO2_Germany_belgium
    ).fit()

    models.append(CO2_Germany_belgium_model)  # append the model to the list of models
    names.append('± ' + str(window) + ' Year')  # append the name of the model to the list of names

table = summary_col(  # create a regression table
    models,  # pass the models to the summary_col function
    stars=True,  # add stars denoting the p-values of the coefficient to the table; * p<0.05, ** p<0.01, *** p<0.001
    float_format='%0.3f',  # set the decimal places to 3
    model_names=names,  # set the names of the model
    info_dict={"N": lambda x: "{0:d}".format(int(x.nobs))}  # add the number of observations to the table
)

print(table)  # print the table
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Annual_CO2_emissions_per_capita'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
for i, model in enumerate(models):
    print(f"± {i + 1} Year:")
    print(model.summary())
    print("\n" + "=" * 80 + "\n")
# Out:
# ± 1 Year:
#                                    OLS Regression Results
# ...
# Dep. Variable:     Annual_CO2_emissions_per_capita   R-squared:                       0.983
# Model:                                         OLS   Adj. R-squared:                  0.957
# Method:                              Least Squares   F-statistic:                     38.49
# Date:                             Mon, 08 Jan 2024   Prob (F-statistic):             0.0254
# Time:                                     18:26:56   Log-Likelihood:                 6.4789
# No. Observations:                                6   AIC:                            -4.958
# Df Residuals:                                    2   BIC:                            -5.791
# Df Model:                                        3
# Covariance Type:                         nonrobust
# ...
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
import matplotlib.pyplot as plt

# Assuming you have datasets C02_per_capita_brazil_timeframe and C02_per_capita_Egypt_timeframe

# Plot for Brazil
plt.figure(figsize=(12, 6))
plt.plot(C02_per_capita_brazil_timeframe['Year'], C02_per_capita_brazil_timeframe['Annual CO₂ emissions (per capita)'], label='Brazil', marker='o')

# Plot for Egypt
plt.plot(C02_per_capita_Egypt_timeframe['Year'], C02_per_capita_Egypt_timeframe['Annual CO₂ emissions (per capita)'], label='Egypt', marker='o')

# Set y-axis to logarithmic scale
plt.yscale('log')

# Set y-axis limit without changing the scale
plt.ylim([1, 6])

plt.xlabel('Year')
plt.ylabel('Annual CO₂ emissions (per capita)')
plt.title('CO₂ Emissions per Capita Over Time - Brazil and Egypt')
plt.legend()
plt.show()

# %%
C02_per_capita_South_Africa = C02_per_capita[C02_per_capita['Entity'] == 'South Africa']
C02_per_capita_South_Africa.head()

C02_per_capita_South_Africa_timeframe = C02_per_capita_South_Africa[(C02_per_capita_South_Africa['Year'] >= 1990) & (C02_per_capita_South_Africa['Year'] <= 2021)]

# Display the first few rows of the filtered data
print(C02_per_capita_South_Africa_timeframe)
# Out:
#              Entity Code  Year  Annual CO₂ emissions (per capita)
# 21907  South Africa  ZAF  1990                           7.847275
# 21908  South Africa  ZAF  1991                           7.969176
# 21909  South Africa  ZAF  1992                           7.215516
# 21910  South Africa  ZAF  1993                           7.533027
# 21911  South Africa  ZAF  1994                           7.827903
# 21912  South Africa  ZAF  1995                           8.222909
# 21913  South Africa  ZAF  1996                           8.144183
# 21914  South Africa  ZAF  1997                           8.506620
# 21915  South Africa  ZAF  1998                           8.227799
# 21916  South Africa  ZAF  1999                           8.085703
# 21917  South Africa  ZAF  2000                           8.081188
# 21918  South Africa  ZAF  2001                           7.868436
# 21919  South Africa  ZAF  2002                           7.480315
# ...

# %%
import matplotlib.pyplot as plt

# Assuming 'C02_per_capita_brazil_timeframe' is the DataFrame for CO2 data within the specified timeframe
# Make sure to replace 'Year' and 'Annual CO₂ emissions (per capita)' with the actual column names in your DataFrame

co2_emissions = C02_per_capita_brazil_timeframe['Annual CO₂ emissions (per capita)']


# Plotting
plt.figure(figsize=(12, 6))
treatment_year1 = 2001
plt.axvline(x=treatment_year1, color='red', linestyle='--', label=f'Bolsa Escola: {treatment_year1}')

treatment_year2 = 2003
plt.axvline(x=treatment_year2, color='yellow', linestyle='--', label=f'Bolsa Família & start of L. I. Lula da Silvas presidency : {treatment_year2}')


plt.plot(year, co2_emissions, marker='o', linestyle='-', color='blue')
plt.title('Annual CO₂ Emissions per Capita in Brazil (1990-2021)')
plt.xlabel('Year')
plt.ylabel('Annual CO₂ emissions (tonnes per person per capita)')
plt.grid(True)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-674-f18a3ed65dd3> in <cell line: 18>()
#      16
#      17
# ---> 18 plt.plot(year, co2_emissions, marker='o', linestyle='-', color='blue')
#      19 plt.title('Annual CO₂ Emissions per Capita in Brazil (1990-2021)')
#      20 plt.xlabel('Year')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2810 @_copy_docstring_and_deprecators(Axes.plot)
#    2811 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2812     return gca().plot(
#    2813         *args, scalex=scalex, scaley=scaley,
#    2814         **({"data": data} if data is not None else {}), **kwargs)
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1686         """
# ...

# %%
import pandas as pd

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df = pd.DataFrame({'Gini': brazil_gini_data.values}, index=brazil_gini_data.index)

# DataFrame for Annual CO₂ emissions (per capita) data
co2_data = pd.DataFrame({'Brazil Annual C02 per Capita ': [1.450887, 1.496018, 1.498395, 1.541938, 1.577843, 1.643137, 1.742448,
                                    1.821151, 1.855469, 1.886351, 1.934246, 1.942441, 1.926925, 1.887129,
                                    1.956637, 1.950622, 1.953552, 2.047249, 2.141657, 2.003804, 2.242226,
                                    2.334078, 2.491823, 2.639368, 2.742072, 2.579841, 2.382041, 2.384218,
                                    2.274380, 2.235612, 2.084953, 2.319858]},
                       index=range(1990, 2022))

GDP_Data_Brazil = pd.DataFrame({'Brazil GDP per Capita ': [10401.843, 10328.957, 10103.788, 10431.409, 10867.751, 11151.191, 11224.399,
                                           11432.650, 11304.097, 11196.839, 11529.486, 11536.364, 11739.432,
                                           11733.411, 12268.664, 12520.855, 12877.444, 13518.848, 14067.946,
                                           13916.963, 14824.741, 15271.470, 15425.353, 15751.484, 15695.644,
                                           15011.577, 14402.494, 14477.861, 14619.591, 14685.128, 14021.958,
                                           14592.353]},
                                index=range(1990, 2022))

# Reindex both DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
co2_data = co2_data.reindex(all_years)
gini_df = gini_df.reindex(all_years)
gdp_df = GDP_Data_Brazil.reindex(all_years)

# Concatenate the DataFrames along the columns axis
combined4 = pd.concat([gini_df, co2_data, gdp_df], axis=1)

# Display the combined dataframe
print(combined4)
# Out:
#       Gini  Brazil Annual C02 per Capita   Brazil GDP per Capita
# Year
# 1990  54.8                       1.450887               10401.843
# 1991  54.4                       1.496018               10328.957
# 1992  53.9                       1.498395               10103.788
# 1993  53.9                       1.541938               10431.409
# 1994  53.9                       1.577843               10867.751
# 1995  53.9                       1.643137               11151.191
# 1996  53.9                       1.742448               11224.399
# 1997  53.8                       1.821151               11432.650
# 1998  53.6                       1.855469               11304.097
# 1999  53.2                       1.886351               11196.839
# 2000  52.9                       1.934246               11529.486
# 2001  52.6                       1.942441               11536.364
# 2002  52.1                       1.926925               11739.432
# ...

# %%
brazil_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Brazil']
brazil_gdp_data
# Out:
#      Entity Code  Year  GDP per capita, PPP (constant 2017 international $)
# 752  Brazil  BRA  1990                                          10401.843
# 753  Brazil  BRA  1991                                          10328.957
# 754  Brazil  BRA  1992                                          10103.788
# 755  Brazil  BRA  1993                                          10431.409
# 756  Brazil  BRA  1994                                          10867.751
# 757  Brazil  BRA  1995                                          11151.191
# 758  Brazil  BRA  1996                                          11224.399
# 759  Brazil  BRA  1997                                          11432.650
# 760  Brazil  BRA  1998                                          11304.097
# 761  Brazil  BRA  1999                                          11196.839
# 762  Brazil  BRA  2000                                          11529.486
# 763  Brazil  BRA  2001                                          11536.364
# ...

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined4.index, combined4['Brazil'], color='blue', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined4.index, combined4['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')

treatment_year1 = 2001
plt.axvline(x=treatment_year1, color='red', linestyle='--', label=f'Bolsa Escola: {treatment_year1}')

treatment_year2 = 2003
plt.axvline(x=treatment_year2, color='yellow', linestyle='--', label=f'Bolsa Família & start of L. I. Lula da Silva\'s presidency: {treatment_year2}')

# Show all years on the x-axis
plt.xticks(combined4.index, rotation=45)

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita) and Gini Index over Years in Brazil (1990-2021)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Brazil'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
brazil_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Brazil']

# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
C02_per_capita_brazil_timeframe = C02_per_capita_brazil[(C02_per_capita_brazil['Year'] >= 1990) & (C02_per_capita_brazil['Year'] <= 2021)]

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df = pd.DataFrame({'Gini': brazil_gini_data.values}, index=brazil_gini_data.index)

# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
gdp_df = pd.DataFrame({'GDP': brazil_gdp_data['GDP per capita, PPP (constant 2017 international $)'].values},
                      index=brazil_gdp_data['Year'])

# Reindex all DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
C02_per_capita_brazil_timeframe = C02_per_capita_brazil_timeframe.set_index('Year').reindex(all_years)

gini_df = gini_df.reindex(all_years)
gdp_df = gdp_df.reindex(all_years)

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(C02_per_capita_brazil_timeframe.index, C02_per_capita_brazil_timeframe['Annual CO₂ emissions (per capita)'], color='blue', marker='o', )
ax1.set_xlabel('Year')
ax1.set_xticks(C02_per_capita_brazil_timeframe.index)
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Set a linear scale for the y-axis

# ... (rest of the code rema ins the same)


# ... (rest of the code remains the same)




ax2 = ax1.twinx()
line2, = ax2.plot(gini_df.index, gini_df['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Add a third y-axis for GDP
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
line3, = ax3.plot(gdp_df.index, gdp_df['GDP'], color='red', marker='o')
ax3.set_ylabel('GDP per capita in $', color='red')
ax3.tick_params(axis='y', labelcolor='red')
# ... (previous code remains the same)

# Show legend for all lines outside the graph on the right side

# ... (rest of the code remains the same)





treatment_year1 = 2001
plt.axvline(x=treatment_year1, color='red', linestyle='--', label=f'Bolsa Escola: {treatment_year1}')

treatment_year2 = 2003
plt.axvline(x=treatment_year2, color='yellow', linestyle='--', label=f'Bolsa Família & start of L. I. Lula da Silvas presidency : {treatment_year2}')





lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(0.1, 0.1 ))

lines = [line1, line2, line3]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(1.2, 1.2), borderaxespad=0.)






# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita), Gini Index, and GDP per Capita over Years in Brazil (1990-2021)')
plt.tight_layout()
plt.legend()
plt.show()

# %%
Germany_gini_data = Gini.loc['Germany']
print(Germany_gini_data)
# Out:
# year
# 1960    29.1
# 1961    28.9
# 1962    28.8
# 1963    28.6
# 1964    28.5
#         ...
# 2018    29.6
# 2019    29.7
# 2020    29.7
# 2021    29.7
# 2022     NaN
# Name: Germany, Length: 63, dtype: float64

# %%
C02_per_capita_Germany = C02_per_capita[C02_per_capita['Entity'] == 'Germany']
C02_per_capita_Germany_timeframe = C02_per_capita_Germany[(C02_per_capita_Germany['Year'] >= 1990) & (C02_per_capita_Germany['Year'] <= 2021)]

print(C02_per_capita_Germany_timeframe)
# Out:
#        Entity Code  Year  Annual CO₂ emissions (per capita)
# 9942  Germany  DEU  1990                          13.288876
# 9943  Germany  DEU  1991                          12.742418
# 9944  Germany  DEU  1992                          12.087449
# 9945  Germany  DEU  1993                          11.906733
# 9946  Germany  DEU  1994                          11.661228
# 9947  Germany  DEU  1995                          11.586038
# 9948  Germany  DEU  1996                          11.803728
# 9949  Germany  DEU  1997                          11.438256
# 9950  Germany  DEU  1998                          11.327495
# 9951  Germany  DEU  1999                          10.978855
# 9952  Germany  DEU  2000                          11.022925
# 9953  Germany  DEU  2001                          11.227958
# 9954  Germany  DEU  2002                          11.036306
# 9955  Germany  DEU  2003                          11.061999
# 9956  Germany  DEU  2004                          10.897857
# ...

# %%
# Assuming 'germany_gini_data' is the DataFrame for Gini data
gini_df_germany = pd.DataFrame({'Gini': Germany_gini_data.values}, index=Germany_gini_data.index)

# DataFrame for Annual CO₂ emissions (per capita) data for Germany
co2_data_germany = pd.DataFrame({'Germany': [13.288876, 12.742418, 12.087449, 11.906733, 11.661228, 11.586038,
                                             11.803728, 11.438256, 11.327495, 10.978855, 11.022925, 11.227958,
                                             11.036306, 11.061999, 10.897857, 10.656909, 10.809575, 10.472896,
                                             10.500914, 9.700711, 10.219843, 9.918698, 9.967624, 10.208109,
                                             9.708648, 9.724056, 9.738013, 9.512761, 9.105443, 8.508805,
                                             7.767432, 8.138241]},
                                index=range(1990, 2022))

# Reindex both DataFrames to ensure they have the same index
all_years_germany = pd.Index(range(1990, 2022), name='Year')
co2_data_germany = co2_data_germany.reindex(all_years_germany)
gini_df_germany = gini_df_germany.reindex(all_years_germany)

# Concatenate the DataFrames along the columns axis
combined_germany = pd.concat([gini_df_germany, co2_data_germany], axis=1)

# Display the combined dataframe
print(combined_germany)
# Out:
#       Gini    Germany
# Year
# 1990  25.9  13.288876
# 1991  26.3  12.742418
# 1992  26.2  12.087449
# 1993  26.0  11.906733
# 1994  25.9  11.661228
# 1995  25.7  11.586038
# 1996  25.4  11.803728
# 1997  25.4  11.438256
# 1998  25.5  11.327495
# 1999  25.9  10.978855
# 2000  26.2  11.022925
# 2001  26.8  11.227958
# 2002  27.0  11.036306
# 2003  27.0  11.061999
# 2004  27.3  10.897857
# 2005  28.2  10.656909
# 2006  28.4  10.809575
# 2007  28.6  10.472896
# 2008  28.6  10.500914
# 2009  28.6   9.700711
# 2010  28.7  10.219843
# 2011  28.8   9.918698
# 2012  29.0   9.967624
# 2013  29.1  10.208109
# 2014  29.1   9.708648
# 2015  29.3   9.724056
# 2016  29.4   9.738013
# 2017  29.5   9.512761
# 2018  29.6   9.105443
# 2019  29.7   8.508805
# 2020  29.7   7.767432
# 2021  29.7   8.138241

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined_germany.index, combined_germany['Germany'], color='blue', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined_germany.index, combined_germany['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')


# Show all years on the x-axis
plt.xticks(combined_germany.index, rotation=45)

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita) and Gini Index over Years in Germany (1990-2021)')
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
Germany_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Germany']

# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
C02_per_capita_Germany_timeframe = C02_per_capita_Germany[(C02_per_capita_Germany['Year'] >= 1990) & (C02_per_capita_Germany['Year'] <= 2021)]

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df_germany = pd.DataFrame({'Gini': Germany_gini_data.values}, index=Germany_gini_data.index)

# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
gdp_df = pd.DataFrame({'GDP': Germany_gdp_data['GDP per capita, PPP (constant 2017 international $)'].values},
                      index=Germany_gdp_data['Year'])

# Reindex all DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
C02_per_capita_Germany_timeframe = C02_per_capita_Germany_timeframe.set_index('Year').reindex(all_years)

gini_df_germany = gini_df_germany.reindex(all_years)
Germany_gdp_data = Germany_gdp_data.reindex(all_years)

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(C02_per_capita_Germany_timeframe.index, C02_per_capita_Germany_timeframe['Annual CO₂ emissions (per capita)'], color='blue', marker='o', )
ax1.set_xlabel('Year')
ax1.set_xticks(C02_per_capita_Germany_timeframe.index)
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Set a linear scale for the y-axis

# ... (rest of the code rema ins the same)


# ... (rest of the code remains the same)




ax2 = ax1.twinx()
line2, = ax2.plot(gini_df_germany.index, gini_df_germany['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Add a third y-axis for GDP
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
line3, = ax3.plot(gdp_df.index, gdp_df['GDP'], color='red', marker='o')
ax3.set_ylabel('GDP per capita in $', color='red')
ax3.tick_params(axis='y', labelcolor='red')
# ... (previous code remains the same)

# Show legend for all lines outside the graph on the right side

# ... (rest of the code remains the same)









lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(0.1, 0.1 ))

lines = [line1, line2, line3]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(1.2, 1.2), borderaxespad=0.)






# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita), Gini Index, and GDP per Capita over Years in Germany   (1990-2021)')
plt.tight_layout()
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
Germany_gdp_data = gdp_per_capita[gdp_per_capita['Entity'] == 'Germany']

# Assuming 'brazil_C02_data' is the DataFrame for CO2 data
C02_per_capita_Germany_timeframe = C02_per_capita_Germany[(C02_per_capita_Germany['Year'] >= 1990) & (C02_per_capita_Germany['Year'] <= 2021)]

# Assuming 'brazil_gini_data' is the DataFrame for Gini data
gini_df_germany = pd.DataFrame({'Gini': Germany_gini_data.values}, index=Germany_gini_data.index)

# Assuming 'brazil_gdp_data' is the DataFrame for GDP data
gdp_df = pd.DataFrame({'GDP': Germany_gdp_data['GDP per capita, PPP (constant 2017 international $)'].values},
                      index=Germany_gdp_data['Year'])

# Reindex all DataFrames to ensure they have the same index
all_years = pd.Index(range(1990, 2022), name='Year')
C02_per_capita_Germany_timeframe = C02_per_capita_Germany_timeframe.set_index('Year').reindex(all_years)

gini_df_germany = gini_df_germany.reindex(all_years)
Germany_gdp_data = Germany_gdp_data.reindex(all_years)

# Plotting
fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(C02_per_capita_Germany_timeframe.index, C02_per_capita_Germany_timeframe['Annual CO₂ emissions (per capita)'], color='blue', marker='o', label='CO₂ Emissions')
ax1.set_xlabel('Year')
ax1.set_xticks(C02_per_capita_Germany_timeframe.index)
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Set a logarithmic scale for the y-axis
ax1.set_yscale('log')

# ... (rest of the code remains the same)

ax2 = ax1.twinx()
line2, = ax2.plot(gini_df_germany.index, gini_df_germany['Gini'], color='green', marker='o', label='Gini Index')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

# Add a third y-axis for GDP
ax3 = ax1.twinx()
ax3.spines['right'].set_position(('outward', 60))
line3, = ax3.plot(gdp_df.index, gdp_df['GDP'], color='red', marker='o', label='GDP per Capita')
ax3.set_ylabel('GDP per capita in $', color='red')
ax3.tick_params(axis='y', labelcolor='red')

# ... (previous code remains the same)

# Show legend for all lines outside the graph on the right side
lines = [line1, line2, line3]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left', bbox_to_anchor=(1.05, 1.0), borderaxespad=0.)

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita), Gini Index, and GDP per Capita over Years in Germany (1990-2021)')
plt.tight_layout()
plt.show()

# %%
C02_per_capita_Germany = C02_per_capita[C02_per_capita['Entity'] == 'Germany']
C02_per_capita_Germany_timeframe = C02_per_capita_Germany[(C02_per_capita_Germany['Year'] >= 1990) & (C02_per_capita_Germany['Year'] <= 2021)]

print(C02_per_capita_Germany_timeframe)
# Out:
#        Entity Code  Year  Annual CO₂ emissions (per capita)
# 9942  Germany  DEU  1990                          13.288876
# 9943  Germany  DEU  1991                          12.742418
# 9944  Germany  DEU  1992                          12.087449
# 9945  Germany  DEU  1993                          11.906733
# 9946  Germany  DEU  1994                          11.661228
# 9947  Germany  DEU  1995                          11.586038
# 9948  Germany  DEU  1996                          11.803728
# 9949  Germany  DEU  1997                          11.438256
# 9950  Germany  DEU  1998                          11.327495
# 9951  Germany  DEU  1999                          10.978855
# 9952  Germany  DEU  2000                          11.022925
# 9953  Germany  DEU  2001                          11.227958
# 9954  Germany  DEU  2002                          11.036306
# 9955  Germany  DEU  2003                          11.061999
# 9956  Germany  DEU  2004                          10.897857
# ...

# %%
Australia_gini_data = Gini.loc['Australia']
print(Australia_gini_data)
# Out:
# year
# 1960     NaN
# 1961     NaN
# 1962     NaN
# 1963     NaN
# 1964     NaN
#         ...
# 2018    32.7
# 2019    32.7
# 2020    32.6
# 2021     NaN
# 2022     NaN
# Name: Australia, Length: 63, dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming Australia_gini_data is a pandas DataFrame or Series with similar structure as Mexico_gini_data

# Replace Mexico_gini_data with Australia_gini_data
plt.figure(figsize=(15, 6))  # Adjust the figure size for a wider plot
plt.plot(Australia_gini_data.index, Australia_gini_data.values, marker='o', linestyle='-', label='Australia')

plt.title('Gini Index for Australia Over the Years')  # Update the title
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.grid(True)


# Set tick frequency to show every year
plt.xticks(range(Australia_gini_data.index.min(), Australia_gini_data.index.max() + 1), rotation=45)

# Adjust the x-axis limits for a wider scale
plt.xlim(Australia_gini_data.index.min() - 1, Australia_gini_data.index.max() + 1)

plt.legend()
plt.show()

# %%
Sweden_gini_data = Gini.loc['Sweden']
print(Sweden_gini_data)
# Out:
# year
# 1960    42.6
# 1961    41.9
# 1962    41.1
# 1963    40.1
# 1964    39.0
#         ...
# 2018    28.5
# 2019    28.6
# 2020    28.6
# 2021    28.9
# 2022     NaN
# Name: Sweden, Length: 63, dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming Sweden_gini_data is a pandas DataFrame or Series with a similar structure as Mexico_gini_data

# Replace Mexico_gini_data with Sweden_gini_data
plt.figure(figsize=(15, 6))  # Adjust the figure size for a wider plot
plt.plot(Sweden_gini_data.index, Sweden_gini_data.values, marker='o', linestyle='-', label='Sweden')

plt.title('Gini Index for Sweden Over the Years')  # Update the title
plt.xlabel('Year')
plt.ylabel('Gini Index')
plt.grid(True)

treatment_year = 1999
plt.axvline(x=treatment_year, color='red', linestyle='--', label=f'Treatment: {treatment_year}')

# Set tick frequency to show every year
plt.xticks(range(Sweden_gini_data.index.min(), Sweden_gini_data.index.max() + 1), rotation=45)

# Adjust the x-axis limits for a wider scale
plt.xlim(Sweden_gini_data.index.min() - 1, Sweden_gini_data.index.max() + 1)

plt.legend()
plt.show()

# %%
C02_per_capita_Sweden = C02_per_capita[C02_per_capita['Entity'] == 'Sweden']
C02_per_capita_Sweden_timeframe = C02_per_capita_Sweden[(C02_per_capita_Sweden['Year'] >= 1990) & (C02_per_capita_Sweden['Year'] <= 2021)]

print(C02_per_capita_Sweden_timeframe)
# Out:
#        Entity Code  Year  Annual CO₂ emissions (per capita)
# 22830  Sweden  SWE  1990                           6.727558
# 22831  Sweden  SWE  1991                           6.718466
# 22832  Sweden  SWE  1992                           6.662662
# 22833  Sweden  SWE  1993                           6.628837
# 22834  Sweden  SWE  1994                           6.879666
# 22835  Sweden  SWE  1995                           6.794108
# 22836  Sweden  SWE  1996                           7.214286
# 22837  Sweden  SWE  1997                           6.628521
# 22838  Sweden  SWE  1998                           6.660359
# 22839  Sweden  SWE  1999                           6.326405
# 22840  Sweden  SWE  2000                           6.192064
# 22841  Sweden  SWE  2001                           6.276178
# 22842  Sweden  SWE  2002                           6.350587
# 22843  Sweden  SWE  2003                           6.393145
# 22844  Sweden  SWE  2004                           6.276685
# ...

# %%
# Assuming 'sweden_gini_data' is the DataFrame for Gini data
gini_df_sweden = pd.DataFrame({'Gini': Sweden_gini_data.values}, index=Sweden_gini_data.index)

# DataFrame for Annual CO₂ emissions (per capita) data for Sweden
co2_data_sweden = pd.DataFrame({'Sweden': [6.727558, 6.718466, 6.662662, 6.628837, 6.879666, 6.794108, 7.214286,
                                           6.628521, 6.660359, 6.326405, 6.192064, 6.276178, 6.350587, 6.393145,
                                           6.276685, 5.951932, 5.902219, 5.782688, 5.511467, 5.078681, 5.662113,
                                           5.197948, 4.888254, 4.684671, 4.459947, 4.408288, 4.361771, 4.221096,
                                           4.136523, 3.993607, 3.538104, 3.680562]},
                                index=range(1990, 2022))

# Reindex both DataFrames to ensure they have the same index
all_years_sweden = pd.Index(range(1990, 2022), name='Year')
co2_data_sweden = co2_data_sweden.reindex(all_years_sweden)
gini_df_sweden = gini_df_sweden.reindex(all_years_sweden)

# Concatenate the DataFrames along the columns axis
combined_sweden = pd.concat([gini_df_sweden, co2_data_sweden], axis=1)

# Display the combined dataframe
print(combined_sweden)
# Out:
#       Gini    Sweden
# Year
# 1990  23.5  6.727558
# 1991  22.9  6.718466
# 1992  23.0  6.662662
# 1993  23.4  6.628837
# 1994  23.7  6.879666
# 1995  23.1  6.794108
# 1996  24.2  7.214286
# 1997  24.8  6.628521
# 1998  25.1  6.660359
# 1999  25.1  6.326405
# 2000  25.0  6.192064
# 2001  24.6  6.276178
# 2002  24.2  6.350587
# 2003  23.8  6.393145
# 2004  24.0  6.276685
# 2005  24.5  5.951932
# 2006  25.2  5.902219
# 2007  25.9  5.782688
# 2008  26.2  5.511467
# 2009  26.8  5.078681
# 2010  27.0  5.662113
# 2011  27.3  5.197948
# 2012  27.4  4.888254
# 2013  27.8  4.684671
# 2014  28.0  4.459947
# 2015  28.3  4.408288
# 2016  28.4  4.361771
# 2017  28.5  4.221096
# 2018  28.5  4.136523
# 2019  28.6  3.993607
# 2020  28.6  3.538104
# 2021  28.9  3.680562

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined_sweden.index, combined_sweden['Sweden'], color='blue', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined_sweden.index, combined_sweden['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')

treatment_year = 1999
plt.axvline(x=treatment_year, color='red', linestyle='--', label=f'Treatment: {treatment_year}')

# Show all years on the x-axis
plt.xticks(combined_sweden.index, rotation=45)

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita) and Gini Index over Years in Sweden (1990-2021)')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax1 = plt.subplots(figsize=(12, 6))

line1, = ax1.plot(combined_germany.index, combined_germany['Germany'], color='blue', marker='o')
ax1.set_xlabel('Year')
ax1.set_ylabel('Annual CO₂ emissions (tonnes per person per capita)', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

ax2 = ax1.twinx()

line2, = ax2.plot(combined_germany.index, combined_germany['Gini'], color='green', marker='o')
ax2.set_ylabel('Gini Index', color='green')
ax2.tick_params(axis='y', labelcolor='green')

lines = [line1, line2]
labels = [line.get_label() for line in lines]
ax1.legend(lines, labels, loc='upper left')


treatment_year = 2005
plt.axvline(x=treatment_year, color='red', linestyle='--', label=f'Hartz 4: {treatment_year}')


# Show all years on the x-axis
plt.xticks(combined_germany.index, rotation=45)

# Show the plot with automatically formatted and rotated x-axis labels
plt.gcf().autofmt_xdate()
plt.title('Annual CO₂ emissions (tonnes per person per capita) and Gini Index over Years in Germany (1990-2021)')
plt.legend()
plt.show()

# %%
# %cd /content/directory
# !rm a.png
# Out:
# [Errno 2] No such file or directory: '/content/directory'
# /content
# rm: cannot remove 'a.png': No such file or directory
